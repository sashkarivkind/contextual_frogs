# %%
import os
if 'ROOT_PATH' in os.environ:
    ROOT_PATH = os.environ['ROOT_PATH']
else:
    ROOT_PATH = '/homes/ar2342/one_more_dir/contextual_frogs/'
    os.environ['ROOT_PATH'] = ROOT_PATH
    
import sys
sys.path.append(ROOT_PATH)

# %%
from __future__ import absolute_import
import importlib


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

from models import MLP, OneOverSqr
from runners import wrap_runner_for_optimization
from fitting_utils import create_fitting_loss
from dsp_utils import smooth_signal

# %%
# !ls
# Out:
# csv_data101	Documents	model_parameters.pth		  one_more_dir
# csv_data102	Downloads	model_parameters.pth_c_model.pth  Pictures
# csv_dataMANI1	early_hist.txt	model_parameters.pth_r_model.pth  Public
# deleteme.ipynb	frogs_project	model_parameters.pth_x_model.pth  Templates
# Desktop		histories	Music				  Videos

# %%
opt_data = {}
for i in range(24):
#     with open(f'../results/sweek_with_shift_{i}.pkl','rb') as f:
    with open(f'{ROOT_PATH}/results/sweek_with_shiftMAE_{i}.pkl','rb') as f:
        opt_data[i] = pickle.load(f)
# Out:
# /tmp/ipykernel_3710238/2220721299.py:5: DeprecationWarning: Please use `OptimizeResult` from the `scipy.optimize` namespace, the `scipy.optimize.optimize` namespace is deprecated.
#   opt_data[i] = pickle.load(f)
# /tmp/ipykernel_3710238/2220721299.py:5: DeprecationWarning: Please use `LbfgsInvHessProduct` from the `scipy.optimize` namespace, the `scipy.optimize.lbfgsb` namespace is deprecated.
#   opt_data[i] = pickle.load(f)

# %%
opt_data
# Out:
# {0: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 6.937018161397665
#                             x: [-4.706e+00  4.589e-02  3.354e-01  3.845e+01]
#                           nit: 100
#         minimization_failures: 7
#                          nfev: 22915
#                          njev: 4583
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 6.937018161397665
#                                       x: [-4.706e+00  4.589e-02  3.354e-01
#                                            3.845e+01]
#                                     nit: 6
#                                     jac: [ 0.000e+00  9.400e-01  8.191e+00
#                                           -1.143e-01]
#                                    nfev: 210
#                                    njev: 42
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  1: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 6.176689817333079
#                             x: [-4.533e+00  6.831e-02  2.746e+00  3.491e+01]
#                           nit: 100
#         minimization_failures: 11
#                          nfev: 20650
#                          njev: 4130
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 6.176689817333079
#                                       x: [-4.533e+00  6.831e-02  2.746e+00
#                                            3.491e+01]
#                                     nit: 1
#                                     jac: [-9.053e+00 -2.205e+00  0.000e+00
#                                            9.311e-03]
#                                    nfev: 15
#                                    njev: 3
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  2: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 3.270962256550912
#                             x: [-4.745e+00  1.439e-01  2.577e-01  4.223e+01]
#                           nit: 100
#         minimization_failures: 10
#                          nfev: 20200
#                          njev: 4040
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.270962256550912
#                                       x: [-4.745e+00  1.439e-01  2.577e-01
#                                            4.223e+01]
#                                     nit: 8
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                           -1.760e-01]
#                                    nfev: 430
#                                    njev: 86
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  3: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 2.4984145371294844
#                             x: [-4.877e+00  1.302e-01  1.147e+00  3.159e+01]
#                           nit: 100
#         minimization_failures: 9
#                          nfev: 23450
#                          njev: 4690
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 2.4984145371294844
#                                       x: [-4.877e+00  1.302e-01  1.147e+00
#                                            3.159e+01]
#                                     nit: 17
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                           -3.936e-03]
#                                    nfev: 590
#                                    njev: 118
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  4: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 3.4022814982789904
#                             x: [-3.955e+00 -9.000e-01  5.462e-02  4.231e+01]
#                           nit: 100
#         minimization_failures: 8
#                          nfev: 20015
#                          njev: 4003
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.4022814982789904
#                                       x: [-3.955e+00 -9.000e-01  5.462e-02
#                                            4.231e+01]
#                                     nit: 16
#                                     jac: [ 0.000e+00  0.000e+00  5.631e+01
#                                           -2.094e-02]
#                                    nfev: 650
#                                    njev: 130
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  5: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 2.7411108307994914
#                             x: [-4.573e+00  3.258e-01  3.000e+00  3.191e+01]
#                           nit: 100
#         minimization_failures: 9
#                          nfev: 22980
#                          njev: 4596
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 2.7411108307994914
#                                       x: [-4.573e+00  3.258e-01  3.000e+00
#                                            3.191e+01]
#                                     nit: 8
#                                     jac: [ 0.000e+00  0.000e+00 -0.000e+00
#                                           -6.624e-04]
#                                    nfev: 415
#                                    njev: 83
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  6: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 3.220783209134832
#                             x: [-4.867e+00  2.092e-01  3.106e-01  4.600e+01]
#                           nit: 100
#         minimization_failures: 6
#                          nfev: 23045
#                          njev: 4609
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.220783209134832
#                                       x: [-4.867e+00  2.092e-01  3.106e-01
#                                            4.600e+01]
#                                     nit: 17
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            8.522e-03]
#                                    nfev: 250
#                                    njev: 50
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  7: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 3.145326122561362
#                             x: [-4.214e+00  1.710e-01  5.000e-02  4.341e+01]
#                           nit: 100
#         minimization_failures: 7
#                          nfev: 18340
#                          njev: 3668
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.145326122561362
#                                       x: [-4.214e+00  1.710e-01  5.000e-02
#                                            4.341e+01]
#                                     nit: 8
#                                     jac: [ 0.000e+00  0.000e+00  1.560e+01
#                                            6.328e-03]
#                                    nfev: 285
#                                    njev: 57
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  8: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 4.5422686184581265
#                             x: [-4.724e+00 -1.566e-01  5.000e-02  4.630e+01]
#                           nit: 100
#         minimization_failures: 10
#                          nfev: 20060
#                          njev: 4012
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 4.5422686184581265
#                                       x: [-4.724e+00 -1.566e-01  5.000e-02
#                                            4.630e+01]
#                                     nit: 11
#                                     jac: [ 0.000e+00  0.000e+00  5.048e+01
#                                           -8.654e-03]
#                                    nfev: 350
#                                    njev: 70
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  9: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 2.5404311152812062
#                             x: [-4.086e+00 -6.083e-01  5.000e-02  4.377e+01]
#                           nit: 100
#         minimization_failures: 8
#                          nfev: 19500
#                          njev: 3900
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 2.5404311152812062
#                                       x: [-4.086e+00 -6.083e-01  5.000e-02
#                                            4.377e+01]
#                                     nit: 6
#                                     jac: [ 0.000e+00  0.000e+00  6.099e+01
#                                            6.868e-03]
#                                    nfev: 180
#                                    njev: 36
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  10: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 3.388805042378833
#                             x: [-4.865e+00  3.999e-01  3.000e+00  3.833e+01]
#                           nit: 100
#         minimization_failures: 5
#                          nfev: 21670
#                          njev: 4334
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.388805042378833
#                                       x: [-4.865e+00  3.999e-01  3.000e+00
#                                            3.833e+01]
#                                     nit: 4
#                                     jac: [ 0.000e+00  0.000e+00 -0.000e+00
#                                            5.799e-03]
#                                    nfev: 110
#                                    njev: 22
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  11: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 4.2264925365248
#                             x: [-4.276e+00  2.793e-02  1.625e-01  3.987e+01]
#                           nit: 100
#         minimization_failures: 4
#                          nfev: 20655
#                          njev: 4131
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 4.2264925365248
#                                       x: [-4.276e+00  2.793e-02  1.625e-01
#                                            3.987e+01]
#                                     nit: 9
#                                     jac: [ 0.000e+00 -9.284e-01  2.010e+01
#                                            1.978e-03]
#                                    nfev: 265
#                                    njev: 53
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  12: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 4.030487653721895
#                             x: [-4.604e+00  2.584e-01  5.925e-02  3.712e+01]
#                           nit: 100
#         minimization_failures: 11
#                          nfev: 22875
#                          njev: 4575
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 4.030487653721895
#                                       x: [-4.604e+00  2.584e-01  5.925e-02
#                                            3.712e+01]
#                                     nit: 4
#                                     jac: [ 0.000e+00  0.000e+00 -9.835e+00
#                                            8.364e-03]
#                                    nfev: 200
#                                    njev: 40
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  13: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 2.986051049563234
#                             x: [-4.654e+00 -3.391e-02  2.493e-01  3.807e+01]
#                           nit: 100
#         minimization_failures: 3
#                          nfev: 20965
#                          njev: 4193
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 2.986051049563234
#                                       x: [-4.654e+00 -3.391e-02  2.493e-01
#                                            3.807e+01]
#                                     nit: 2
#                                     jac: [ 0.000e+00  1.545e+01  0.000e+00
#                                           -3.493e-02]
#                                    nfev: 190
#                                    njev: 38
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  14: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 4.888018390776429
#                             x: [-4.586e+00 -5.080e-01  8.102e-02  4.056e+01]
#                           nit: 100
#         minimization_failures: 8
#                          nfev: 20230
#                          njev: 4046
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 4.888018390776429
#                                       x: [-4.586e+00 -5.080e-01  8.102e-02
#                                            4.056e+01]
#                                     nit: 6
#                                     jac: [ 0.000e+00  0.000e+00 -9.173e+00
#                                            5.787e-02]
#                                    nfev: 250
#                                    njev: 50
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  15: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 3.932226907421915
#                             x: [-4.792e+00 -1.458e-01  4.591e-01  3.842e+01]
#                           nit: 100
#         minimization_failures: 5
#                          nfev: 19800
#                          njev: 3960
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.932226907421915
#                                       x: [-4.792e+00 -1.458e-01  4.591e-01
#                                            3.842e+01]
#                                     nit: 10
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            8.615e-04]
#                                    nfev: 515
#                                    njev: 103
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  16: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 6.118930252531981
#                             x: [-4.908e+00  1.078e-01  5.000e-02  4.924e+01]
#                           nit: 100
#         minimization_failures: 6
#                          nfev: 22170
#                          njev: 4434
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 6.118930252531981
#                                       x: [-4.908e+00  1.078e-01  5.000e-02
#                                            4.924e+01]
#                                     nit: 3
#                                     jac: [ 0.000e+00 -4.873e-01  2.542e+01
#                                            1.492e-02]
#                                    nfev: 240
#                                    njev: 48
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  17: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 3.985221566556267
#                             x: [-4.250e+00  4.894e-01  2.675e+00  4.792e+01]
#                           nit: 100
#         minimization_failures: 5
#                          nfev: 22290
#                          njev: 4458
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.985221566556267
#                                       x: [-4.250e+00  4.894e-01  2.675e+00
#                                            4.792e+01]
#                                     nit: 18
#                                     jac: [ 1.747e+01  0.000e+00  0.000e+00
#                                            6.897e-03]
#                                    nfev: 445
#                                    njev: 89
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  18: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 4.950132204956356
#                             x: [-4.619e+00 -6.222e-01  5.000e-02  4.069e+01]
#                           nit: 100
#         minimization_failures: 7
#                          nfev: 25015
#                          njev: 5003
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 4.950132204956356
#                                       x: [-4.619e+00 -6.222e-01  5.000e-02
#                                            4.069e+01]
#                                     nit: 3
#                                     jac: [ 0.000e+00  0.000e+00  3.126e+01
#                                           -1.141e-01]
#                                    nfev: 160
#                                    njev: 32
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  19: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 3.6764797390045927
#                             x: [-4.395e+00 -9.000e-01  2.332e-01  4.296e+01]
#                           nit: 100
#         minimization_failures: 11
#                          nfev: 20985
#                          njev: 4197
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.6764797390045927
#                                       x: [-4.395e+00 -9.000e-01  2.332e-01
#                                            4.296e+01]
#                                     nit: 14
#                                     jac: [ 0.000e+00  0.000e+00  3.661e+01
#                                           -1.051e-03]
#                                    nfev: 480
#                                    njev: 96
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  20: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 3.0835939971747517
#                             x: [-4.475e+00  7.800e-01  4.523e-01  4.132e+01]
#                           nit: 100
#         minimization_failures: 8
#                          nfev: 23955
#                          njev: 4791
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 3.0835939971747517
#                                       x: [-4.475e+00  7.800e-01  4.523e-01
#                                            4.132e+01]
#                                     nit: 0
#                                     jac: [ 4.270e+00  0.000e+00  0.000e+00
#                                           -5.237e-02]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  21: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 7.787323254015817
#                             x: [-4.583e+00 -3.415e-02  5.475e-02  4.904e+01]
#                           nit: 100
#         minimization_failures: 14
#                          nfev: 21180
#                          njev: 4236
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 7.787323254015817
#                                       x: [-4.583e+00 -3.415e-02  5.475e-02
#                                            4.904e+01]
#                                     nit: 25
#                                     jac: [ 0.000e+00 -1.848e+01  2.016e+01
#                                            2.056e-03]
#                                    nfev: 750
#                                    njev: 150
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  22: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 6.2297900190525075
#                             x: [-4.799e+00 -2.236e-01  5.000e-02  4.055e+01]
#                           nit: 100
#         minimization_failures: 10
#                          nfev: 22040
#                          njev: 4408
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 6.2297900190525075
#                                       x: [-4.799e+00 -2.236e-01  5.000e-02
#                                            4.055e+01]
#                                     nit: 7
#                                     jac: [ 0.000e+00  0.000e+00  1.298e+01
#                                            3.925e-04]
#                                    nfev: 340
#                                    njev: 68
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  23: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 2.0358580798132113
#                             x: [-4.321e+00  9.900e-01  5.131e-02  4.196e+01]
#                           nit: 100
#         minimization_failures: 10
#                          nfev: 26600
#                          njev: 5320
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 2.0358580798132113
#                                       x: [-4.321e+00  9.900e-01  5.131e-02
#                                            4.196e+01]
#                                     nit: 4
#                                     jac: [ 2.188e+00 -0.000e+00  1.466e+00
#                                            5.462e-02]
#                                    nfev: 185
#                                    njev: 37
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>}}

# %%
def scale_and_bias(x,bias=0,scale=45.0):
    x = np.array(x)
    return x*scale + bias
fixed_params = {}
fixed_params['model'] =  dict(n_inputs = 3,
        n_hidden = 5*4*512,
        n_outs = 1,
        en_bias = False,
        b_high=3, first_layer_init='ones',
        first_layer_weights_trainable = True,
        out_layer_init='zeros')         

fixed_params['runner'] = {'criterion':'MSE', 'k':[0,1,0], 'sigma_noi':0.0, 'tau_u':1,
                        'save_model_at_init':False, 'ic_param_file':None}

optim_param_mapping= [('custom','normalized_log_lr'),
                    ('model','skip_gain'),                      
                    ('custom','w'),
                    ('postprocessing','scale'),
                    ]

custom_param_mappings = [{'cathegory':'runner','param_name':'learning_rate',
                            'fun': lambda x: 10.**x['normalized_log_lr']/x['w']},
                            {'cathegory':'model','param_name':'nl','fun': lambda x: (lambda : OneOverSqr(w=x['w']))}]

wrapped_runner = wrap_runner_for_optimization(model_class=MLP, 
                                             fixed_params=fixed_params,
                                             optim_params_mapping=optim_param_mapping,
                                              custom_param_mappings =custom_param_mappings,
                                             postprocessing_fun=scale_and_bias)

# %%
df = pd.read_csv(f'{ROOT_PATH}/../../frogs_project/data/avraham__ivry_fig1_rotFig1_v2.csv',header=None)
df = df.T
data = df.to_numpy()

# %%
stimulus = [(1,40),(0,40)]
pooling_fun = 'MAE'

# %%
errors = [opt_data[k][pooling_fun]['fun'] for k in opt_data]

# %%
np.mean(errors)
# Out:
# 4.158112369184072

# %%
outs  = {k: wrapped_runner([(1,40),(0,40),(1,41)],opt_data[k][pooling_fun]['x']) for k in opt_data}

# %%
plt.figure(figsize=(15,15))
for k in opt_data:
    plt.subplot(5,5,k+1)
    plt.plot(outs[k][1:])
    plt.plot(data[:,k],'.')
    plt.plot(data[:80,k],'.')
    if k<5: plt.title(f'{k+1}')
        

plt.subplot(5,5,1)
plt.ylabel('adaptation angle [deg]')
plt.xlabel('cycle')

plt.gca().set_title(f'subjects -->>{1}', pad=-30)
plt.legend(['model','validation data','fitted data'])    
    
# plt.plot(data[:80,0],'.')
# plt.plot(smooth_signal(data[:,0],3))

# %%
    
plt.figure(figsize=(15,15))
for k in opt_data:
    plt.subplot(5,5,k+1)
    ydata_model_train = outs[k][1:81]
    ydata_model_test = outs[k][80:]
    ydata_experiment = data[:,k]
    xdata_model_train = np.arange(1,81)
    xdata_model_test = np.arange(80,121)
    xdata_experiment = np.arange(1,121)
    plt.plot(xdata_experiment,ydata_experiment,'b.')
    plt.plot(xdata_model_train,ydata_model_train,'r-')
    plt.plot(xdata_model_test,ydata_model_test,'r--')
    np.savetxt(f'{ROOT_PATH}/results/avraham_subj_{k+1}_model_train.csv', np.array([xdata_model_train,ydata_model_train]).T, delimiter=',')
    np.savetxt(f'{ROOT_PATH}/results/avraham_subj_{k+1}_model_test.csv', np.array([xdata_model_test,ydata_model_test]).T, delimiter=',')
    np.savetxt(f'{ROOT_PATH}/results/avraham_subj_{k+1}_experiment.csv', np.array([xdata_experiment,ydata_experiment]).T, delimiter=',')

    # plt.plot(outs[k][1:])
    # plt.plot(data[:,k],'.')
    # plt.plot(data[:80,k],'.')
    # if k<5: plt.title(f'{k+1}')
        

plt.subplot(5,5,1)
plt.ylabel('adaptation angle [deg]')
plt.xlabel('cycle')

plt.gca().set_title(f'subjects -->>{1}', pad=-30)
plt.legend(['model','validation data','fitted data'])

# %%
# xdata_experiment.shape,ydata_experiment.shape
xdata_model_train.shape,ydata_model_train.shape
# Out:
# ((80,), (80,))

# %%
plt.subplot(1,1,1)
plt.ylabel('adaptation angle [deg]')
plt.xlabel('cycle')

plt.gca().set_title(f'subjects -->>{1}', pad=-3000)
plt.legend(['model','validation data','fitted data'])

# %%
plt.figure(figsize=(15,15))
for k in opt_data:
    plt.subplot(5,5,k+1)
    plt.plot(outs[k][1:])
    plt.plot(smooth_signal(data[:,k],3),'.')

# %%
outs_ = [o[1:] for _,o in outs.items()]
outs_ = np.array(outs_)

# %%
plt.plot(np.mean(outs_,axis=0))
plt.plot(np.mean(data,axis=1))

# %%
diffs = outs_.T-data
np.mean(diffs[:80,:]**2),np.mean(diffs[80:,:]**2)
# Out:
# (77.66298747125691, 39.997709873666025)

# %%
data_varia = data-np.mean(data,axis=1,keepdims=True)

# %%
np.mean(data_varia**2)
# Out:
# 83.27901569878472

# %%
np.mean(diffs[:80,:]**2),np.mean(diffs[80:,:]**2),np.mean(diffs[81:,:]**2)
# Out:
# (77.66298747125691, 39.997709873666025, 36.6799425022624)

# %%
np.mean(data_varia[:80,:]**2),np.mean(data_varia[80:,:]**2),np.mean(data_varia[81:,:]**2)
# Out:
# (99.77897536675346, 50.27909636284723, 46.55323259882478)

# %%
plt.plot(diffs[:,80:])
# Out:
# []

# %%
A_times = [0,5,10,20] 
antero   = {aa: [ wrapped_runner([(1,A_time),(-1,40)],opt_data[k][pooling_fun]['x']) for k in opt_data] for aa,A_time in enumerate(A_times)}

# %%
for aa,A_time in enumerate(A_times):
    y = np.mean(antero[aa],axis=0)
    x = np.arange(len(y))
    x = x - x[-1]
    plt.plot(x,y)

# %%
frog_ens = [True,False]
Tfrog = 220
frogs   = {aa: [ wrapped_runner([(1 if not frog_en else np.linspace(0,1,Tfrog),Tfrog),(0,40)],opt_data[k][pooling_fun]['x']) for k in opt_data] for aa,frog_en in enumerate(frog_ens)}

# %%
for frog_en in frog_ens:
    plt.plot(np.mean(frogs[frog_en],axis=0))

# %%
for setting in pooling_funs +[appendix]:
    plt.plot(outs[setting])
plt.plot(data[:,0],'x')
plt.plot(data[:80,0],'x')

plt.xlim([39,120])
plt.ylim([-5,60])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 for setting in pooling_funs +[appendix]:
#       2     plt.plot(outs[setting])
#       3 plt.plot(data[:,0],'x')
#
# NameError: name 'pooling_funs' is not defined

# %%
mae = lambda x: np.mean(np.abs(x))
mse = lambda x: np.mean(np.square(x))

# %%
for setting in pooling_funs +[appendix]:
    fit_err = outs[setting][:80] - data[:80,0]
    val_err = outs[setting][80:] - data[80:,0]
    print(f'fit objective: {setting}')
    print(f' fitting MAE: {mae(fit_err)}; MSE: {mse(fit_err)}')
    print(f' validation MAE: {mae(val_err)}; MSE: {mse(val_err)}')

# %%
import scipy
scipy.__version__

# %%
# !pip3 install --upgrade pip

# %%
# pip install --upgrade scipy

# %%
import pickle

# %%
with open('sweep_1_subj_12.pkl','rb') as f:
    opt_data = pickle.load(f)

# %%
opt_data
