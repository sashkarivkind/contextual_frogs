# %%
import sys

# Specify the directory you want to add
custom_path = './..'

# Add the directory to sys.path
if custom_path not in sys.path:
    sys.path.append(custom_path)

# %%
from __future__ import absolute_import
import importlib


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

from models import MLP, OneOverSqr
from runners import wrap_runner_for_optimization
from fitting_utils import create_fitting_loss
from dsp_utils import smooth_signal

# %%
# !ls
# Out:
# DELETE_THIS_empty.ipynb		       sweep_1_subj_20.pkl
# ZZZZ_nl_experiments_tanh.ipynb	       sweep_1_subj_21.pkl
# ZZZ_bkp_oldReLU.ipynb		       sweep_1_subj_22.pkl
# ZZZ_delete_nl_experiments-Copy4.ipynb  sweep_1_subj_23.pkl
# __init__.py			       sweep_1_subj_3.pkl
# antifrog_demo.ipynb		       sweep_1_subj_4.pkl
# avraham_data_bringup.ipynb	       sweep_1_subj_5.pkl
# collect_fitting_info101.ipynb	       sweep_1_subj_6.pkl
# deleteme_0.pkl			       sweep_1_subj_7.pkl
# fit_single_v1.py		       sweep_1_subj_8.pkl
# frog_gain.ipynb			       sweep_1_subj_9.pkl
# gauss_kernel_encoder.ipynb	       sweep_3a_subj_0.log
# hello_world_fitting.ipynb	       sweep_3a_subj_1.log
# hello_world_fitting102.ipynb	       sweep_3a_subj_10.log
# model_parameters.pth		       sweep_3a_subj_11.log
# nl_experiments.ipynb		       sweep_3a_subj_12.log
# nl_experiments_OneOverSq.ipynb	       sweep_3a_subj_13.log
# nl_visualisation.ipynb		       sweep_3a_subj_14.log
# nl_width_sweep.ipynb		       sweep_3a_subj_15.log
# nl_width_sweep_multilayer.ipynb        sweep_3a_subj_16.log
# opt_out_subject_id_0.pkl	       sweep_3a_subj_17.log
# overlearning_insights.ipynb	       sweep_3a_subj_18.log
# sigmoid_experiments.ipynb	       sweep_3a_subj_19.log
# sweep_1_subj_0.pkl		       sweep_3a_subj_2.log
# sweep_1_subj_1.pkl		       sweep_3a_subj_20.log
# sweep_1_subj_10.pkl		       sweep_3a_subj_21.log
# sweep_1_subj_11.pkl		       sweep_3a_subj_22.log
# sweep_1_subj_12.pkl		       sweep_3a_subj_23.log
# sweep_1_subj_13.pkl		       sweep_3a_subj_3.log
# sweep_1_subj_14.pkl		       sweep_3a_subj_4.log
# sweep_1_subj_15.pkl		       sweep_3a_subj_5.log
# sweep_1_subj_16.pkl		       sweep_3a_subj_6.log
# sweep_1_subj_17.pkl		       sweep_3a_subj_7.log
# sweep_1_subj_18.pkl		       sweep_3a_subj_8.log
# sweep_1_subj_19.pkl		       sweep_3a_subj_9.log
# sweep_1_subj_2.pkl		       sweep_subjects.sh

# %%
opt_data = {}
for i in range(24):
    with open(f'sweep_1_subj_{i}.pkl','rb') as f:
        opt_data[i] = pickle.load(f)
# Out:
# /tmp/ipykernel_15022/2584052752.py:4: DeprecationWarning: Please use `OptimizeResult` from the `scipy.optimize` namespace, the `scipy.optimize.optimize` namespace is deprecated.
#   opt_data[i] = pickle.load(f)
# /tmp/ipykernel_15022/2584052752.py:4: DeprecationWarning: Please use `LbfgsInvHessProduct` from the `scipy.optimize` namespace, the `scipy.optimize.lbfgsb` namespace is deprecated.
#   opt_data[i] = pickle.load(f)

# %%
opt_data
# Out:
# {0: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 206.09561926494894
#                             x: [-4.914e+00 -2.306e-01  2.710e+00  3.446e+01]
#                           nit: 50
#         minimization_failures: 8
#                          nfev: 3975
#                          njev: 795
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 206.09561926494894
#                                       x: [-4.914e+00 -2.306e-01  2.710e+00
#                                            3.446e+01]
#                                     nit: 8
#                                     jac: [ 0.000e+00  7.780e+02  0.000e+00
#                                            3.638e-04]
#                                    nfev: 250
#                                    njev: 50
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  1: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 121.29959909500306
#                             x: [-4.811e+00  3.118e-01  1.575e+00  3.557e+01]
#                           nit: 50
#         minimization_failures: 6
#                          nfev: 4760
#                          njev: 952
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 121.29959909500306
#                                       x: [-4.811e+00  3.118e-01  1.575e+00
#                                            3.557e+01]
#                                     nit: 3
#                                     jac: [ 3.097e+02  0.000e+00  0.000e+00
#                                           -5.952e-01]
#                                    nfev: 300
#                                    njev: 60
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  2: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 40.75286628064232
#                             x: [-4.500e+00  4.000e-01  5.000e-01  4.201e+01]
#                           nit: 50
#         minimization_failures: 7
#                          nfev: 3770
#                          njev: 754
#    lowest_optimization_result:  message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                 success: True
#                                  status: 0
#                                     fun: 40.75286628064232
#                                       x: [-4.500e+00  4.000e-01  5.000e-01
#                                            4.201e+01]
#                                     nit: 2
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            7.105e-07]
#                                    nfev: 15
#                                    njev: 3
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  3: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 11.300366982695044
#                             x: [-4.891e+00  2.246e-01  1.017e+00  3.106e+01]
#                           nit: 50
#         minimization_failures: 6
#                          nfev: 3545
#                          njev: 709
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 11.300366982695044
#                                       x: [-4.891e+00  2.246e-01  1.017e+00
#                                            3.106e+01]
#                                     nit: 6
#                                     jac: [ 0.000e+00  8.353e+01  0.000e+00
#                                            1.776e-07]
#                                    nfev: 180
#                                    njev: 36
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  4: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 80.66581655833916
#                             x: [-4.481e+00  3.419e-01  1.950e+00  4.070e+01]
#                           nit: 50
#         minimization_failures: 4
#                          nfev: 2990
#                          njev: 598
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 80.66581655833916
#                                       x: [-4.481e+00  3.419e-01  1.950e+00
#                                            4.070e+01]
#                                     nit: 4
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            7.913e-02]
#                                    nfev: 210
#                                    njev: 42
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  5: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 16.163445442166896
#                             x: [-4.788e+00  3.992e-01  1.196e+00  3.265e+01]
#                           nit: 50
#         minimization_failures: 4
#                          nfev: 5030
#                          njev: 1006
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 16.163445442166896
#                                       x: [-4.788e+00  3.992e-01  1.196e+00
#                                            3.265e+01]
#                                     nit: 11
#                                     jac: [ 0.000e+00  1.541e+02  0.000e+00
#                                            4.515e-04]
#                                    nfev: 260
#                                    njev: 52
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  6: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 37.23838214508387
#                             x: [-4.444e+00  3.289e-01  5.658e-01  4.101e+01]
#                           nit: 50
#         minimization_failures: 7
#                          nfev: 3530
#                          njev: 706
#    lowest_optimization_result:  message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                 success: True
#                                  status: 0
#                                     fun: 37.23838214508387
#                                       x: [-4.444e+00  3.289e-01  5.658e-01
#                                            4.101e+01]
#                                     nit: 3
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                           -6.395e-06]
#                                    nfev: 55
#                                    njev: 11
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  7: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 40.4135138445602
#                             x: [-3.827e+00 -2.049e-01  5.165e-01  4.187e+01]
#                           nit: 50
#         minimization_failures: 7
#                          nfev: 3530
#                          njev: 706
#    lowest_optimization_result:  message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                 success: True
#                                  status: 0
#                                     fun: 40.4135138445602
#                                       x: [-3.827e+00 -2.049e-01  5.165e-01
#                                            4.187e+01]
#                                     nit: 2
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            0.000e+00]
#                                    nfev: 15
#                                    njev: 3
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  8: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 56.69258064792872
#                             x: [-3.888e+00 -3.186e-02  1.212e-01  4.206e+01]
#                           nit: 50
#         minimization_failures: 5
#                          nfev: 8445
#                          njev: 1689
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 56.69258064792872
#                                       x: [-3.888e+00 -3.186e-02  1.212e-01
#                                            4.206e+01]
#                                     nit: 19
#                                     jac: [ 0.000e+00  4.382e+02  1.257e+02
#                                           -1.346e+00]
#                                    nfev: 910
#                                    njev: 182
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  9: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 40.49431949554412
#                             x: [-3.642e+00  2.407e-01  3.324e-01  4.289e+01]
#                           nit: 50
#         minimization_failures: 7
#                          nfev: 4175
#                          njev: 835
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 40.49431949554412
#                                       x: [-3.642e+00  2.407e-01  3.324e-01
#                                            4.289e+01]
#                                     nit: 6
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                           -2.412e-03]
#                                    nfev: 120
#                                    njev: 24
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  10: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 37.79290694015007
#                             x: [-4.904e+00  3.638e-01  1.393e+00  3.563e+01]
#                           nit: 50
#         minimization_failures: 7
#                          nfev: 4235
#                          njev: 847
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 37.79290694015007
#                                       x: [-4.904e+00  3.638e-01  1.393e+00
#                                            3.563e+01]
#                                     nit: 10
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                           -1.499e-04]
#                                    nfev: 180
#                                    njev: 36
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  11: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 47.56852359167947
#                             x: [-4.291e+00  5.323e-01  7.193e-01  3.700e+01]
#                           nit: 50
#         minimization_failures: 9
#                          nfev: 1480
#                          njev: 296
#    lowest_optimization_result:  message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                 success: True
#                                  status: 0
#                                     fun: 47.56852359167947
#                                       x: [-4.291e+00  5.323e-01  7.193e-01
#                                            3.700e+01]
#                                     nit: 2
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            0.000e+00]
#                                    nfev: 15
#                                    njev: 3
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  12: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 54.20185131762064
#                             x: [-3.856e+00  5.428e-01  2.564e-01  3.433e+01]
#                           nit: 50
#         minimization_failures: 5
#                          nfev: 3725
#                          njev: 745
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 54.20185131762064
#                                       x: [-3.856e+00  5.428e-01  2.564e-01
#                                            3.433e+01]
#                                     nit: 3
#                                     jac: [ 0.000e+00  0.000e+00 -8.886e-01
#                                            1.811e-02]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  13: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 24.04750053056754
#                             x: [-4.108e+00  1.891e-01  3.222e-01  3.672e+01]
#                           nit: 50
#         minimization_failures: 11
#                          nfev: 3430
#                          njev: 686
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 24.04750053056754
#                                       x: [-4.108e+00  1.891e-01  3.222e-01
#                                            3.672e+01]
#                                     nit: 7
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            3.024e-01]
#                                    nfev: 260
#                                    njev: 52
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  14: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 159.6614375452218
#                             x: [-4.361e+00  1.482e-01  5.224e-01  3.893e+01]
#                           nit: 50
#         minimization_failures: 5
#                          nfev: 3535
#                          njev: 707
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 159.6614375452218
#                                       x: [-4.361e+00  1.482e-01  5.224e-01
#                                            3.893e+01]
#                                     nit: 8
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            8.527e-05]
#                                    nfev: 155
#                                    njev: 31
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  15: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 75.28301540282276
#                             x: [-4.556e+00 -5.081e-02  5.131e-01  3.513e+01]
#                           nit: 50
#         minimization_failures: 6
#                          nfev: 4065
#                          njev: 813
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 75.28301540282276
#                                       x: [-4.556e+00 -5.081e-02  5.131e-01
#                                            3.513e+01]
#                                     nit: 4
#                                     jac: [ 0.000e+00  1.351e+01  0.000e+00
#                                           -1.703e+00]
#                                    nfev: 140
#                                    njev: 28
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  16: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 142.62003709340786
#                             x: [-4.326e+00  5.150e-03  2.514e-01  5.135e+01]
#                           nit: 50
#         minimization_failures: 8
#                          nfev: 4330
#                          njev: 866
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 142.62003709340786
#                                       x: [-4.326e+00  5.150e-03  2.514e-01
#                                            5.135e+01]
#                                     nit: 9
#                                     jac: [ 0.000e+00  8.751e+02  6.797e+02
#                                           -4.764e-02]
#                                    nfev: 290
#                                    njev: 58
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  17: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 63.47867570539273
#                             x: [-4.124e+00  8.054e-01  3.985e-01  4.400e+01]
#                           nit: 50
#         minimization_failures: 5
#                          nfev: 2950
#                          njev: 590
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 63.47867570539273
#                                       x: [-4.124e+00  8.054e-01  3.985e-01
#                                            4.400e+01]
#                                     nit: 5
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            9.180e-03]
#                                    nfev: 185
#                                    njev: 37
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  18: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 102.74395374318608
#                             x: [-3.688e+00 -5.272e-01  1.222e-01  3.992e+01]
#                           nit: 50
#         minimization_failures: 6
#                          nfev: 5805
#                          njev: 1161
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 102.74395374318608
#                                       x: [-3.688e+00 -5.272e-01  1.222e-01
#                                            3.992e+01]
#                                     nit: 9
#                                     jac: [ 0.000e+00  0.000e+00  3.008e+01
#                                           -1.563e-05]
#                                    nfev: 195
#                                    njev: 39
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  19: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 51.046510201907026
#                             x: [-3.912e+00 -5.260e-02  3.222e-01  4.028e+01]
#                           nit: 50
#         minimization_failures: 5
#                          nfev: 4985
#                          njev: 997
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 51.046510201907026
#                                       x: [-3.912e+00 -5.260e-02  3.222e-01
#                                            4.028e+01]
#                                     nit: 5
#                                     jac: [ 0.000e+00 -2.458e+02  7.989e+01
#                                           -6.116e-01]
#                                    nfev: 165
#                                    njev: 33
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  20: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 39.79595781367642
#                             x: [-3.735e+00  4.723e-01  5.145e-01  4.076e+01]
#                           nit: 50
#         minimization_failures: 28
#                          nfev: 4205
#                          njev: 841
#    lowest_optimization_result:  message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                 success: True
#                                  status: 0
#                                     fun: 39.79595781367642
#                                       x: [-3.735e+00  4.723e-01  5.145e-01
#                                            4.076e+01]
#                                     nit: 9
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                           -4.974e-06]
#                                    nfev: 145
#                                    njev: 29
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  21: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 297.6233474376244
#                             x: [-3.729e+00 -7.566e-01  1.820e-01  4.116e+01]
#                           nit: 50
#         minimization_failures: 6
#                          nfev: 4090
#                          njev: 818
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 297.6233474376244
#                                       x: [-3.729e+00 -7.566e-01  1.820e-01
#                                            4.116e+01]
#                                     nit: 5
#                                     jac: [ 0.000e+00  0.000e+00  7.174e+02
#                                           -2.775e+00]
#                                    nfev: 170
#                                    njev: 34
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  22: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 230.92472706775638
#                             x: [-4.226e+00  3.919e-01  2.683e-01  3.356e+01]
#                           nit: 50
#         minimization_failures: 9
#                          nfev: 5540
#                          njev: 1108
#    lowest_optimization_result:  message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                 success: True
#                                  status: 0
#                                     fun: 230.92472706775638
#                                       x: [-4.226e+00  3.919e-01  2.683e-01
#                                            3.356e+01]
#                                     nit: 3
#                                     jac: [ 0.000e+00  0.000e+00  0.000e+00
#                                            0.000e+00]
#                                    nfev: 20
#                                    njev: 4
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  23: {'MSE':                     message: ['requested number of basinhopping iterations completed successfully']
#                           fun: 25.717520293053582
#                             x: [-4.217e+00  9.900e-01  5.312e-01  4.103e+01]
#                           nit: 50
#         minimization_failures: 3
#                          nfev: 2370
#                          njev: 474
#    lowest_optimization_result:  message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                 success: True
#                                  status: 0
#                                     fun: 25.717520293053582
#                                       x: [-4.217e+00  9.900e-01  5.312e-01
#                                            4.103e+01]
#                                     nit: 2
#                                     jac: [ 0.000e+00 -0.000e+00  0.000e+00
#                                           -7.105e-07]
#                                    nfev: 15
#                                    njev: 3
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>}}

# %%
fixed_params = {}


fixed_params['model'] =  dict(n_inputs = 3,
                  n_hidden = 5*4*512,
                  n_outs = 1,
                  en_bias = False,
                 b_high=3, first_layer_init='ones',
                first_layer_weights_trainable = True,
                out_layer_init='zeros')         
#todo - tie "kernel width" to learning rate 
fixed_params['runner'] = {'criterion':'MSE', 'k':[0,1,0], 'sigma_noi':0.0, 'tau_u':1,
                          'save_model_at_init':False, 'ic_param_file':None}

def scale_and_bias(x,bias=0,scale=45.0):
    x = np.array(x)
    return x*scale + bias
#to sweep

# nl = lambda : OneOverSqr(w=w), 
# skip_gain= skip
# , 'learning_rate':1e-5

optim_param_mapping= [('runner','learning_rate',lambda x: 10.**x), 
                      ('model','skip_gain'), 
                      ('model','nl',
                       lambda w: (lambda : OneOverSqr(w=w))),
                     ('postprocessing','scale')]

wrapped_runner = wrap_runner_for_optimization(model_class=MLP, 
                                             fixed_params=fixed_params,
                                             optim_params_mapping=optim_param_mapping,
                                             postprocessing_fun=scale_and_bias)

# %%
df = pd.read_csv('../../../frogs_project/data/avraham__ivry_fig1_rotFig1_v2.csv',header=None)
df = df.T
data = df.to_numpy()

# %%
stimulus = [(1,40),(0,40)]
pooling_fun = 'MSE'

# %%
errors = [opt_data[k][pooling_fun]['fun'] for k in opt_data]

# %%
np.mean(errors)
# Out:
# 83.48426976837412

# %%
outs  = {k: wrapped_runner([(1,40),(0,40)],opt_data[k][pooling_fun]['x']) for k in opt_data}

# %%
plt.figure(figsize=(15,15))
for k in opt_data:
    plt.subplot(5,5,k+1)
    plt.plot(outs[k])
    plt.plot(data[:80,k],'.')
# plt.plot(data[:80,0],'.')
# plt.plot(smooth_signal(data[:,0],3))

# %%
plt.figure(figsize=(15,15))
for k in opt_data:
    plt.subplot(5,5,k+1)
    plt.plot(outs[k])
    plt.plot(smooth_signal(data[:80,k],3),'.')

# %%
data

# %%
for setting in pooling_funs +[appendix]:
    plt.plot(outs[setting])
plt.plot(data[:,0],'x')
plt.plot(data[:80,0],'x')

plt.xlim([39,120])
plt.ylim([-5,60])

# %%
mae = lambda x: np.mean(np.abs(x))
mse = lambda x: np.mean(np.square(x))

# %%
for setting in pooling_funs +[appendix]:
    fit_err = outs[setting][:80] - data[:80,0]
    val_err = outs[setting][80:] - data[80:,0]
    print(f'fit objective: {setting}')
    print(f' fitting MAE: {mae(fit_err)}; MSE: {mse(fit_err)}')
    print(f' validation MAE: {mae(val_err)}; MSE: {mse(val_err)}')

# %%
import scipy
scipy.__version__

# %%
# !pip3 install --upgrade pip

# %%
# pip install --upgrade scipy

# %%
import pickle

# %%
with open('sweep_1_subj_12.pkl','rb') as f:
    opt_data = pickle.load(f)

# %%
opt_data
