# %%
# load a matrix from a space-separated file and show it as an image
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch

# %%
data_ = np.load('/homes/ar2342/one_more_dir/contextual_frogs/experimental/optim/results/temp_trajs/paradigms.npz')
data = dict(data_)

# %%
for key in data:
    plt.figure()
    plt.title(key)
    plt.plot(np.mean(data[key],axis=1))
    break
