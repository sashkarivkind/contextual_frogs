# %%
import os
if 'ROOT_PATH' in os.environ:
    ROOT_PATH = os.environ['ROOT_PATH']
else:
    ROOT_PATH = '/homes/ar2342/one_more_dir/contextual_frogs/'
    os.environ['ROOT_PATH'] = ROOT_PATH
    
import sys
sys.path.append(ROOT_PATH)

# %%
from __future__ import absolute_import
import importlib


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

from models import MLP, OneOverSqr
from runners import wrap_runner_for_optimization
from fitting_utils import create_fitting_loss
from dsp_utils import smooth_signal

from types import SimpleNamespace

# %%
args = SimpleNamespace()
args.paradigm = 'evoked'

# %%
opt_data = {}
for i in range(1,9):
    # with open(f'../results/sweek_with_shift_{i}.pkl','rb') as f:
    with open(f'{ROOT_PATH}/experimental/coin_evoked_run002_MAE_{i}.pkl','rb') as f:
        opt_data[i] = pickle.load(f)

# %%
opt_data
# Out:
# {1: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: False
#                           fun: 0.10221404683655472
#                             x: [-3.802e+00  3.519e-01  2.577e-01  1.062e+00]
#                           nit: 150
#         minimization_failures: 21
#                          nfev: 19620
#                          njev: 3924
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 0.10221404683655472
#                                       x: [-3.802e+00  3.519e-01  2.577e-01
#                                            1.062e+00]
#                                     nit: 0
#                                     jac: [-4.006e+04  2.083e+05  5.282e+04
#                                            9.728e+04]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  2: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: False
#                           fun: 0.07330995407120434
#                             x: [-6.000e+00  1.965e-01  1.836e-01  9.974e-01]
#                           nit: 150
#         minimization_failures: 25
#                          nfev: 17975
#                          njev: 3595
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 0.07330995407120434
#                                       x: [-6.000e+00  1.965e-01  1.836e-01
#                                            9.974e-01]
#                                     nit: 0
#                                     jac: [ 4.200e+05  2.330e+05  1.060e+05
#                                            2.839e+05]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  3: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 0.0723851876047351
#                             x: [-3.658e+00  7.107e-01  4.484e-01  8.075e-01]
#                           nit: 150
#         minimization_failures: 27
#                          nfev: 18500
#                          njev: 3700
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 0.0723851876047351
#                                       x: [-3.658e+00  7.107e-01  4.484e-01
#                                            8.075e-01]
#                                     nit: 4
#                                     jac: [ 1.059e+05  1.092e+04 -1.115e+05
#                                            1.037e+05]
#                                    nfev: 175
#                                    njev: 35
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  4: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 0.08084982796839651
#                             x: [-4.306e+00  7.802e-01  5.000e-01  9.870e-01]
#                           nit: 150
#         minimization_failures: 19
#                          nfev: 19360
#                          njev: 3872
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 0.08084982796839651
#                                       x: [-4.306e+00  7.802e-01  5.000e-01
#                                            9.870e-01]
#                                     nit: 2
#                                     jac: [-1.218e+04  9.244e+04  2.554e+02
#                                            4.106e+04]
#                                    nfev: 115
#                                    njev: 23
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  5: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 0.0919464576428148
#                             x: [-3.000e+00  2.537e-01  2.221e-01  8.666e-01]
#                           nit: 150
#         minimization_failures: 25
#                          nfev: 18705
#                          njev: 3741
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 0.0919464576428148
#                                       x: [-3.000e+00  2.537e-01  2.221e-01
#                                            8.666e-01]
#                                     nit: 2
#                                     jac: [ 1.099e+05  4.319e+04  1.524e+05
#                                            5.407e+04]
#                                    nfev: 145
#                                    njev: 29
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  6: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: False
#                           fun: 0.08258736425355688
#                             x: [-3.039e+00  5.536e-01  5.000e-01  6.493e-01]
#                           nit: 150
#         minimization_failures: 28
#                          nfev: 18670
#                          njev: 3734
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 0.08258736425355688
#                                       x: [-3.039e+00  5.536e-01  5.000e-01
#                                            6.493e-01]
#                                     nit: 0
#                                     jac: [ 6.717e+04  1.694e+04 -7.992e+04
#                                            8.866e+04]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  7: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 0.08511898208192734
#                             x: [-3.069e+00  3.047e-01  1.006e-01  6.097e-01]
#                           nit: 150
#         minimization_failures: 29
#                          nfev: 19400
#                          njev: 3880
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 0.08511898208192734
#                                       x: [-3.069e+00  3.047e-01  1.006e-01
#                                            6.097e-01]
#                                     nit: 2
#                                     jac: [-5.914e+03  9.277e+03  5.279e+04
#                                           -2.029e+04]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  8: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 0.08333753946569387
#                             x: [-4.065e+00  1.423e-01  1.757e-01  1.100e+00]
#                           nit: 150
#         minimization_failures: 34
#                          nfev: 19005
#                          njev: 3801
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 0.08333753946569387
#                                       x: [-4.065e+00  1.423e-01  1.757e-01
#                                            1.100e+00]
#                                     nit: 2
#                                     jac: [-1.754e+05 -1.325e+05 -2.067e+05
#                                           -2.243e+05]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>}}

# %%
def scale_and_bias(x,bias=0,scale=45.0):
    x = np.array(x)
    return x*scale + bias
fixed_params = {}


fixed_params['model'] =  dict(n_inputs = 4,
                        n_hidden = 5*4*512,
                        n_outs = 1,
                        en_bias = False,
                        first_layer_init='uniform_unity',
                    first_layer_weights_trainable = True,
                    out_layer_init='zeros',
                        nl = 'relu')        

fixed_params['runner'] = {'criterion':'MSE', 'k':[0,0,0,1],  'sigma_noi':0.0, 'tau_u':1,
                        'save_model_at_init':False, 'ic_param_file':None, 'enable_combo':True}

optim_param_mapping= [('custom','normalized_log_lr'),
                    ('model','skip_gain'),                      
                    ('model','b_high'),                      
                    ('postprocessing','scale'),
                    ]
custom_param_mappings = []

wrapped_runner = wrap_runner_for_optimization(model_class=MLP, 
                                             fixed_params=fixed_params,
                                             optim_params_mapping=optim_param_mapping,
                                              custom_param_mappings =custom_param_mappings,
                                             postprocessing_fun=scale_and_bias)

# %%
Pplus = 1
Pminus = -1
P0 = 0
Pchannel = np.nan

'''
spontaneous:
trials in block Null: 50
trials in block FieldA: 120
trials in block PostRest: 5
trials in block FieldB: 15
trials in block Clamp150: 150


evoked:
trials in block Null: 50
trials in block FieldA: 120
trials in block PostRest: 5
trials in block FieldB: 15
trials in block Clamp2: 2
trials in block FieldA2: 2
trials in block Clamp150: 146
'''
stimuli = {'spontaneous': [(P0, 50),
                        (Pplus, 120),
                        (Pminus, 15),
                        (Pchannel, 150)],
            'evoked': [(P0, 50),
                        (Pplus, 125),
                        (Pminus, 15),
                        (Pchannel, 2),
                        (Pplus, 2),
                        (Pchannel, 146)]}

data = {}
for i in range(1,9):
    df = pd.read_csv(f'{ROOT_PATH}/../../frogs_project/data/COIN_data/trial_data_{args.paradigm}_recovery_participant{i}.csv')
    y = df.Adaptation.to_numpy()
    y *= np.sign(np.nansum(y))
    data[i] = y
stimulus = stimuli[args.paradigm]
datapoint_mapping=None

# %%
pooling_fun = 'MAE'

# %%
errors = [opt_data[k][pooling_fun]['fun'] for k in opt_data]

# %%
np.mean(errors)
# Out:
# 0.08396866999061045

# %%
opt_data.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5, 6, 7, 8])

# %%
stimulus
# Out:
# [(0, 50), (1, 125), (-1, 15), (nan, 2), (1, 2), (nan, 146)]

# %%
# debu   = {k: wrapped_runner([stimulus],opt_data[k][pooling_fun]['x']) for k in opt_data}

# %%
outs  = {k: wrapped_runner(stimulus,opt_data[k][pooling_fun]['x']) for k in opt_data}

# %%
plt.figure(figsize=(15,7.5))
for k in opt_data:
    plt.subplot(2,4,k)
    plt.plot(outs[k],linewidth=2)
    plt.plot(data[k],'.', alpha=0.3)
    if k<5: plt.title(f'{k+1}')
        

plt.subplot(2,4,1)
plt.ylabel('adaptation angle [deg]')
plt.xlabel('cycle')

plt.gca().set_title(f'subjects -->>{1}', pad=-30)
plt.legend(['model','validation data','fitted data'])    
    
# plt.plot(data[:80,0],'.')
# plt.plot(smooth_signal(data[:,0],3))

# %%
plt.subplot(1,1,1)
plt.ylabel('adaptation angle [deg]')
plt.xlabel('cycle')

plt.gca().set_title(f'subjects -->>{1}', pad=-3000)
plt.legend(['model','validation data','fitted data'])

# %%
plt.figure(figsize=(15,15))
for k in opt_data:
    plt.subplot(5,5,k+1)
    plt.plot(outs[k][1:])
    plt.plot(smooth_signal(data[:,k],3),'.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 5
#       3 plt.subplot(5,5,k+1)
#       4 plt.plot(outs[k][1:])
# ----> 5 plt.plot(smooth_signal(data[:,k],3),'.')
#
# TypeError: unhashable type: 'slice'

# %%
outs_ = [o for _,o in outs.items()]
outs_ = np.array(outs_)
data_ = np.array([data[k] for k in opt_data])

# %%
plt.plot(np.mean(outs_,axis=0))
plt.plot(np.nanmean(data_,axis=0),'.')
# Out:
# /tmp/ipykernel_1007498/23407626.py:2: RuntimeWarning: Mean of empty slice
#   plt.plot(np.nanmean(data_,axis=0),'.')

# %%
diffs = outs_.T-data
np.mean(diffs[:80,:]**2),np.mean(diffs[80:,:]**2)
# Out:
# (69.63715568182214, 71.17979145353007)

# %%
A_times = [0,5,10,20] 
antero   = {aa: [ wrapped_runner([(1,A_time),(-1,40)],opt_data[k][pooling_fun]['x']) for k in opt_data] for aa,A_time in enumerate(A_times)}

# %%
for aa,A_time in enumerate(A_times):
    y = np.mean(antero[aa],axis=0)
    x = np.arange(len(y))
    x = x - x[-1]
    plt.plot(x,y)

# %%
frog_ens = [True,False]
Tfrog = 400
frogs   = {aa: [ wrapped_runner([(1 if not frog_en else np.linspace(0,1,Tfrog),Tfrog),(0,40)],opt_data[k][pooling_fun]['x']) for k in opt_data] for aa,frog_en in enumerate(frog_ens)}

# %%
for frog_en in frog_ens:
    plt.plot(np.mean(frogs[frog_en],axis=0))

# %%
for setting in pooling_funs +[appendix]:
    plt.plot(outs[setting])
plt.plot(data[:,0],'x')
plt.plot(data[:80,0],'x')

plt.xlim([39,120])
plt.ylim([-5,60])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 for setting in pooling_funs +[appendix]:
#       2     plt.plot(outs[setting])
#       3 plt.plot(data[:,0],'x')
#
# NameError: name 'pooling_funs' is not defined

# %%
mae = lambda x: np.mean(np.abs(x))
mse = lambda x: np.mean(np.square(x))

# %%
for setting in pooling_funs +[appendix]:
    fit_err = outs[setting][:80] - data[:80,0]
    val_err = outs[setting][80:] - data[80:,0]
    print(f'fit objective: {setting}')
    print(f' fitting MAE: {mae(fit_err)}; MSE: {mse(fit_err)}')
    print(f' validation MAE: {mae(val_err)}; MSE: {mse(val_err)}')

# %%
import scipy
scipy.__version__

# %%
# !pip3 install --upgrade pip

# %%
# pip install --upgrade scipy

# %%
import pickle

# %%
with open('sweep_1_subj_12.pkl','rb') as f:
    opt_data = pickle.load(f)

# %%
opt_data
