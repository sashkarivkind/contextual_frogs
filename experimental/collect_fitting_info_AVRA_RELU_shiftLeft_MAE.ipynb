# %%
import os
if 'ROOT_PATH' in os.environ:
    ROOT_PATH = os.environ['ROOT_PATH']
else:
    ROOT_PATH = '/homes/ar2342/one_more_dir/contextual_frogs/'
    os.environ['ROOT_PATH'] = ROOT_PATH
    
import sys
sys.path.append(ROOT_PATH)

# %%
from __future__ import absolute_import
import importlib


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

from models import MLP, OneOverSqr
from runners import wrap_runner_for_optimization
from fitting_utils import create_fitting_loss
from dsp_utils import smooth_signal

# %%
# !ls
# Out:
# deleteme.ipynb	Downloads	histories	      one_more_dir  Templates
# Desktop		early_hist.txt	model_parameters.pth  Pictures	    Videos
# Documents	frogs_project	Music		      Public

# %%
opt_data = {}
for i in range(24):
#     with open(f'../results/sweek_with_shift_{i}.pkl','rb') as f:
    with open(f'{ROOT_PATH}/experimental/avraham_relu_run001_MAE_{i}.pkl','rb') as f:
        opt_data[i] = pickle.load(f)

# %%
opt_data
# Out:
# {0: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 7.852898607964368
#                             x: [-4.556e+00 -1.000e-01  1.000e-02  4.017e+01]
#                           nit: 150
#         minimization_failures: 37
#                          nfev: 17245
#                          njev: 3449
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 7.852898607964368
#                                       x: [-4.556e+00 -1.000e-01  1.000e-02
#                                            4.017e+01]
#                                     nit: 1
#                                     jac: [-4.834e+04 -6.242e+05 -4.939e+05
#                                           -1.096e+06]
#                                    nfev: 100
#                                    njev: 20
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  1: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 6.3319852552526
#                             x: [-4.883e+00 -1.072e-02  1.282e+00  3.678e+01]
#                           nit: 150
#         minimization_failures: 33
#                          nfev: 18430
#                          njev: 3686
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 6.3319852552526
#                                       x: [-4.883e+00 -1.072e-02  1.282e+00
#                                            3.678e+01]
#                                     nit: 2
#                                     jac: [ 3.963e+05 -2.776e+06 -3.490e+06
#                                           -6.852e+05]
#                                    nfev: 130
#                                    njev: 26
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  2: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 3.597679456936585
#                             x: [-4.573e+00  1.842e-01  1.012e+00  4.020e+01]
#                           nit: 150
#         minimization_failures: 50
#                          nfev: 17770
#                          njev: 3554
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.597679456936585
#                                       x: [-4.573e+00  1.842e-01  1.012e+00
#                                            4.020e+01]
#                                     nit: 2
#                                     jac: [-7.223e+05 -9.990e+04 -4.488e+05
#                                           -8.686e+05]
#                                    nfev: 90
#                                    njev: 18
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  3: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 3.6965875229341036
#                             x: [-5.173e+00  9.156e-02  9.944e-01  3.943e+01]
#                           nit: 150
#         minimization_failures: 37
#                          nfev: 17985
#                          njev: 3597
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.6965875229341036
#                                       x: [-5.173e+00  9.156e-02  9.944e-01
#                                            3.943e+01]
#                                     nit: 2
#                                     jac: [-8.306e+05  5.968e+05 -2.794e+06
#                                           -7.754e+05]
#                                    nfev: 120
#                                    njev: 24
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  4: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 3.899557870063427
#                             x: [-3.996e+00 -1.000e-01  9.865e-01  4.266e+01]
#                           nit: 150
#         minimization_failures: 40
#                          nfev: 17610
#                          njev: 3522
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.899557870063427
#                                       x: [-3.996e+00 -1.000e-01  9.865e-01
#                                            4.266e+01]
#                                     nit: 1
#                                     jac: [-3.275e+05 -3.051e+05 -9.766e+05
#                                           -3.080e+04]
#                                    nfev: 15
#                                    njev: 3
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  5: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: False
#                           fun: 3.549636331963248
#                             x: [-4.885e+00  4.134e-01  2.907e-01  3.990e+01]
#                           nit: 150
#         minimization_failures: 39
#                          nfev: 19380
#                          njev: 3876
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 3.549636331963248
#                                       x: [-4.885e+00  4.134e-01  2.907e-01
#                                            3.990e+01]
#                                     nit: 0
#                                     jac: [ 1.208e+06 -1.756e+05 -2.971e+05
#                                            2.055e+06]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  6: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 2.982139911729049
#                             x: [-4.657e+00  2.792e-01  9.106e-01  4.103e+01]
#                           nit: 150
#         minimization_failures: 43
#                          nfev: 18345
#                          njev: 3669
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 2.982139911729049
#                                       x: [-4.657e+00  2.792e-01  9.106e-01
#                                            4.103e+01]
#                                     nit: 3
#                                     jac: [-7.043e+05 -1.373e+06  4.208e+05
#                                           -1.894e+06]
#                                    nfev: 165
#                                    njev: 33
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  7: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 3.4524739724715374
#                             x: [-4.296e+00  1.733e-01  1.000e-02  4.486e+01]
#                           nit: 150
#         minimization_failures: 38
#                          nfev: 19050
#                          njev: 3810
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.4524739724715374
#                                       x: [-4.296e+00  1.733e-01  1.000e-02
#                                            4.486e+01]
#                                     nit: 1
#                                     jac: [-4.175e+05  3.218e+06 -7.048e+05
#                                           -1.228e+05]
#                                    nfev: 75
#                                    njev: 15
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  8: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: False
#                           fun: 5.4366453803883115
#                             x: [-4.527e+00  8.031e-02  1.249e-01  3.964e+01]
#                           nit: 150
#         minimization_failures: 49
#                          nfev: 18215
#                          njev: 3643
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 5.4366453803883115
#                                       x: [-4.527e+00  8.031e-02  1.249e-01
#                                            3.964e+01]
#                                     nit: 0
#                                     jac: [-2.497e+04  1.718e+05 -2.891e+04
#                                            4.631e+05]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  9: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: False
#                           fun: 4.1997106620782745
#                             x: [-4.062e+00  3.226e-01  5.790e-01  3.888e+01]
#                           nit: 150
#         minimization_failures: 47
#                          nfev: 18020
#                          njev: 3604
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 4.1997106620782745
#                                       x: [-4.062e+00  3.226e-01  5.790e-01
#                                            3.888e+01]
#                                     nit: 0
#                                     jac: [ 8.717e+05  9.974e+05  7.827e+05
#                                            1.630e+06]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  10: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 3.920555444383754
#                             x: [-5.562e+00  4.203e-01  2.000e+00  4.098e+01]
#                           nit: 150
#         minimization_failures: 47
#                          nfev: 18655
#                          njev: 3731
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.920555444383754
#                                       x: [-5.562e+00  4.203e-01  2.000e+00
#                                            4.098e+01]
#                                     nit: 1
#                                     jac: [-9.988e+05 -8.763e+05  1.356e+06
#                                           -1.360e+06]
#                                    nfev: 15
#                                    njev: 3
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  11: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 4.2992841870457745
#                             x: [-3.899e+00 -1.000e-01  6.574e-01  3.757e+01]
#                           nit: 150
#         minimization_failures: 47
#                          nfev: 17420
#                          njev: 3484
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 4.2992841870457745
#                                       x: [-3.899e+00 -1.000e-01  6.574e-01
#                                            3.757e+01]
#                                     nit: 1
#                                     jac: [-5.214e+05 -5.318e+05 -3.205e+05
#                                           -4.967e+05]
#                                    nfev: 95
#                                    njev: 19
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  12: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 3.9426824217433754
#                             x: [-4.154e+00 -1.343e-02  1.000e-02  3.730e+01]
#                           nit: 150
#         minimization_failures: 42
#                          nfev: 18185
#                          njev: 3637
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.9426824217433754
#                                       x: [-4.154e+00 -1.343e-02  1.000e-02
#                                            3.730e+01]
#                                     nit: 2
#                                     jac: [-1.903e+05 -4.126e+05 -5.730e+05
#                                           -2.169e+05]
#                                    nfev: 115
#                                    njev: 23
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  13: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 3.308737460566514
#                             x: [-4.636e+00  2.848e-01  1.000e-02  3.896e+01]
#                           nit: 150
#         minimization_failures: 51
#                          nfev: 18010
#                          njev: 3602
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.308737460566514
#                                       x: [-4.636e+00  2.848e-01  1.000e-02
#                                            3.896e+01]
#                                     nit: 2
#                                     jac: [ 1.227e+05 -1.717e+05 -3.953e+05
#                                           -1.317e+04]
#                                    nfev: 90
#                                    njev: 18
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  14: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 5.536127336372397
#                             x: [-4.456e+00 -1.000e-01  1.000e-02  3.850e+01]
#                           nit: 150
#         minimization_failures: 40
#                          nfev: 17475
#                          njev: 3495
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 5.536127336372397
#                                       x: [-4.456e+00 -1.000e-01  1.000e-02
#                                            3.850e+01]
#                                     nit: 1
#                                     jac: [-3.356e+06 -4.354e+06 -3.939e+06
#                                           -4.866e+06]
#                                    nfev: 15
#                                    njev: 3
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  15: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 4.940860880980037
#                             x: [-4.693e+00 -1.000e-01  1.737e-01  4.066e+01]
#                           nit: 150
#         minimization_failures: 45
#                          nfev: 18445
#                          njev: 3689
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 4.940860880980037
#                                       x: [-4.693e+00 -1.000e-01  1.737e-01
#                                            4.066e+01]
#                                     nit: 1
#                                     jac: [ 1.213e+06 -1.787e+06 -3.316e+05
#                                           -3.613e+05]
#                                    nfev: 75
#                                    njev: 15
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  16: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 7.216448977359448
#                             x: [-4.440e+00 -1.000e-01  2.051e-01  4.121e+01]
#                           nit: 150
#         minimization_failures: 48
#                          nfev: 17805
#                          njev: 3561
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 7.216448977359448
#                                       x: [-4.440e+00 -1.000e-01  2.051e-01
#                                            4.121e+01]
#                                     nit: 3
#                                     jac: [-4.521e+06 -4.370e+06 -3.135e+06
#                                           -4.191e+06]
#                                    nfev: 115
#                                    njev: 23
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  17: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 4.696735070666243
#                             x: [-3.652e+00 -1.000e-01  4.444e-01  4.146e+01]
#                           nit: 150
#         minimization_failures: 41
#                          nfev: 19005
#                          njev: 3801
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 4.696735070666243
#                                       x: [-3.652e+00 -1.000e-01  4.444e-01
#                                            4.146e+01]
#                                     nit: 2
#                                     jac: [ 7.791e+05  5.056e+04 -2.843e+05
#                                            3.845e+04]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  18: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 5.682619415006819
#                             x: [-4.509e+00 -1.000e-01  5.442e-02  3.983e+01]
#                           nit: 150
#         minimization_failures: 40
#                          nfev: 18245
#                          njev: 3649
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 5.682619415006819
#                                       x: [-4.509e+00 -1.000e-01  5.442e-02
#                                            3.983e+01]
#                                     nit: 2
#                                     jac: [ 5.451e+05  2.398e+06  8.253e+05
#                                            1.927e+06]
#                                    nfev: 145
#                                    njev: 29
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  19: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 4.141924848413867
#                             x: [-4.415e+00  5.648e-03  6.443e-01  4.002e+01]
#                           nit: 150
#         minimization_failures: 39
#                          nfev: 18845
#                          njev: 3769
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 4.141924848413867
#                                       x: [-4.415e+00  5.648e-03  6.443e-01
#                                            4.002e+01]
#                                     nit: 5
#                                     jac: [ 7.381e+05  3.098e+06 -2.197e+06
#                                            5.578e+05]
#                                    nfev: 180
#                                    njev: 36
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  20: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 3.1000450089659983
#                             x: [-4.099e+00  1.069e-01  1.192e+00  3.899e+01]
#                           nit: 150
#         minimization_failures: 45
#                          nfev: 17760
#                          njev: 3552
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 3.1000450089659983
#                                       x: [-4.099e+00  1.069e-01  1.192e+00
#                                            3.899e+01]
#                                     nit: 1
#                                     jac: [ 1.274e+04 -2.977e+04  3.122e+04
#                                            3.145e+04]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  21: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: False
#                           fun: 9.107974613180417
#                             x: [-4.205e+00  4.117e-02  1.000e-02  4.029e+01]
#                           nit: 150
#         minimization_failures: 37
#                          nfev: 18055
#                          njev: 3611
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 9.107974613180417
#                                       x: [-4.205e+00  4.117e-02  1.000e-02
#                                            4.029e+01]
#                                     nit: 1
#                                     jac: [ 4.095e+05  1.201e+06  7.824e+05
#                                            4.194e+05]
#                                    nfev: 115
#                                    njev: 23
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  22: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: True
#                           fun: 6.401312734184242
#                             x: [-4.633e+00 -1.000e-01  1.000e-02  4.159e+01]
#                           nit: 150
#         minimization_failures: 41
#                          nfev: 19110
#                          njev: 3822
#    lowest_optimization_result:  message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                 success: True
#                                  status: 0
#                                     fun: 6.401312734184242
#                                       x: [-4.633e+00 -1.000e-01  1.000e-02
#                                            4.159e+01]
#                                     nit: 4
#                                     jac: [ 1.566e+06  1.336e+06  1.561e+06
#                                           -1.646e+06]
#                                    nfev: 150
#                                    njev: 30
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>},
#  23: {'MAE':                     message: ['requested number of basinhopping iterations completed successfully']
#                       success: False
#                           fun: 2.004208259503195
#                             x: [-3.757e+00 -1.000e-01  9.743e-01  4.127e+01]
#                           nit: 150
#         minimization_failures: 48
#                          nfev: 18790
#                          njev: 3758
#    lowest_optimization_result:  message: ABNORMAL_TERMINATION_IN_LNSRCH
#                                 success: False
#                                  status: 2
#                                     fun: 2.004208259503195
#                                       x: [-3.757e+00 -1.000e-01  9.743e-01
#                                            4.127e+01]
#                                     nit: 0
#                                     jac: [ 5.988e+05  9.829e+05  4.043e+05
#                                            1.316e+06]
#                                    nfev: 105
#                                    njev: 21
#                                hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>}}

# %%
def scale_and_bias(x,bias=0,scale=45.0):
    x = np.array(x)
    return x*scale + bias
fixed_params['model'] =  dict(n_inputs = 4,
                          n_hidden = 5*4*512,
                          n_outs = 1,
                          en_bias = False,
                         first_layer_init='uniform_unity',
                        first_layer_weights_trainable = True,
                        out_layer_init='zeros',
                          nl = 'relu')        

fixed_params['runner'] = {'criterion':'MSE', 'k':[0,0,0,1],  'sigma_noi':0.0, 'tau_u':1,
                        'save_model_at_init':False, 'ic_param_file':None, 'enable_combo':True}

optim_param_mapping= [('custom','normalized_log_lr'),
                    ('model','skip_gain'),                      
                    ('model','b_high'),                      
                    ('postprocessing','scale'),
                    ]
custom_param_mappings = [{'cathegory':'runner','param_name':'learning_rate',
                        'fun': lambda x: 10.**x['normalized_log_lr']},]



wrapped_runner = wrap_runner_for_optimization(model_class=MLP, 
                                             fixed_params=fixed_params,
                                             optim_params_mapping=optim_param_mapping,
                                             custom_param_mappings=custom_param_mappings, 
                                             postprocessing_fun=scale_and_bias)

# %%
df = pd.read_csv(f'{ROOT_PATH}/../../frogs_project/data/avraham__ivry_fig1_rotFig1_v2.csv',header=None)
df = df.T
data = df.to_numpy()

# %%
stimulus = [(1,40),(0,40)]
pooling_fun = 'MAE'

# %%
errors = [opt_data[k][pooling_fun]['fun'] for k in opt_data]

# %%
np.mean(errors)
# Out:
# 4.720784651256399

# %%
outs  = {k: wrapped_runner([(1,40),(0,40),(1,41)],opt_data[k][pooling_fun]['x']) for k in opt_data}

# %%
plt.figure(figsize=(15,15))
for k in opt_data:
    plt.subplot(5,5,k+1)
    plt.plot(outs[k][1:])
    plt.plot(data[:,k],'.')
    plt.plot(data[:80,k],'.')
    if k<5: plt.title(f'{k+1}')
        

plt.subplot(5,5,1)
plt.ylabel('adaptation angle [deg]')
plt.xlabel('cycle')

plt.gca().set_title(f'subjects -->>{1}', pad=-30)
plt.legend(['model','validation data','fitted data'])    
    
# plt.plot(data[:80,0],'.')
# plt.plot(smooth_signal(data[:,0],3))

# %%
plt.subplot(1,1,1)
plt.ylabel('adaptation angle [deg]')
plt.xlabel('cycle')

plt.gca().set_title(f'subjects -->>{1}', pad=-3000)
plt.legend(['model','validation data','fitted data'])

# %%
plt.figure(figsize=(15,15))
for k in opt_data:
    plt.subplot(5,5,k+1)
    plt.plot(outs[k][1:])
    plt.plot(smooth_signal(data[:,k],3),'.')

# %%
outs_ = [o[1:] for _,o in outs.items()]
outs_ = np.array(outs_)

# %%
plt.plot(np.mean(outs_,axis=0))
plt.plot(np.mean(data,axis=1))

# %%
diffs = outs_.T-data
np.mean(diffs[:80,:]**2),np.mean(diffs[80:,:]**2)
# Out:
# (77.66298747125691, 39.997709873666025)

# %%
data_varia = data-np.mean(data,axis=1,keepdims=True)

# %%
np.mean(data_varia**2)
# Out:
# 83.27901569878472

# %%
np.mean(diffs[:80,:]**2),np.mean(diffs[80:,:]**2),np.mean(diffs[81:,:]**2)
# Out:
# (77.66298747125691, 39.997709873666025, 36.6799425022624)

# %%
np.mean(data_varia[:80,:]**2),np.mean(data_varia[80:,:]**2),np.mean(data_varia[81:,:]**2)
# Out:
# (99.77897536675346, 50.27909636284723, 46.55323259882478)

# %%
plt.plot(diffs[:,80:])
# Out:
# []

# %%
A_times = [0,5,10,20] 
antero   = {aa: [ wrapped_runner([(1,A_time),(-1,40)],opt_data[k][pooling_fun]['x']) for k in opt_data] for aa,A_time in enumerate(A_times)}

# %%
for aa,A_time in enumerate(A_times):
    y = np.mean(antero[aa],axis=0)
    x = np.arange(len(y))
    x = x - x[-1]
    plt.plot(x,y)

# %%
frog_ens = [True,False]
Tfrog = 220
frogs   = {aa: [ wrapped_runner([(1 if not frog_en else np.linspace(0,1,Tfrog),Tfrog),(0,40)],opt_data[k][pooling_fun]['x']) for k in opt_data] for aa,frog_en in enumerate(frog_ens)}

# %%
for frog_en in frog_ens:
    plt.plot(np.mean(frogs[frog_en],axis=0))

# %%
for setting in pooling_funs +[appendix]:
    plt.plot(outs[setting])
plt.plot(data[:,0],'x')
plt.plot(data[:80,0],'x')

plt.xlim([39,120])
plt.ylim([-5,60])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 for setting in pooling_funs +[appendix]:
#       2     plt.plot(outs[setting])
#       3 plt.plot(data[:,0],'x')
#
# NameError: name 'pooling_funs' is not defined

# %%
mae = lambda x: np.mean(np.abs(x))
mse = lambda x: np.mean(np.square(x))

# %%
for setting in pooling_funs +[appendix]:
    fit_err = outs[setting][:80] - data[:80,0]
    val_err = outs[setting][80:] - data[80:,0]
    print(f'fit objective: {setting}')
    print(f' fitting MAE: {mae(fit_err)}; MSE: {mse(fit_err)}')
    print(f' validation MAE: {mae(val_err)}; MSE: {mse(val_err)}')

# %%
import scipy
scipy.__version__

# %%
# !pip3 install --upgrade pip

# %%
# pip install --upgrade scipy

# %%
import pickle

# %%
with open('sweep_1_subj_12.pkl','rb') as f:
    opt_data = pickle.load(f)

# %%
opt_data
