# %%
from __future__ import absolute_import

#check if there is an evirronment variable called ROOT_PATH
import os
if 'ROOT_PATH' in os.environ:
    ROOT_PATH = os.environ['ROOT_PATH']
else:
    ROOT_PATH = '/homes/ar2342/one_more_dir/contextual_frogs/'
    os.environ['ROOT_PATH'] = ROOT_PATH
    
import sys
sys.path.append(ROOT_PATH)

# %%
from __future__ import absolute_import
import importlib

from copy import copy

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

from types import SimpleNamespace

import matplotlib.pyplot as plt
from models import MLP, OneOverSqr, DualRateModel, Herzfeld14Model
from coin_if import COINWrapper
from dsp_utils import seg_time
from siggen_utils import herzfeld_block
from plt_utils import plot_by_key,plot_segments

from runners import Runner

# %%
P0=0
Pplus=1
Pminus=-1
Pchannel=np.nan

TfN1 = 100
TfA = 300
TfN2 = 100

TsN=60
TsA=120
TsB=20
TsC=20

# T=300
TaN=150
TaB=120*5

playlist = {
'frogs': [(P0,TfN1),((P0,Pplus),TfA),(P0,TfN2)],
'anti_frogs': [(P0,TfN1),(Pplus,TfA),(P0,TfN2)],
'savings': 2 * [(P0, TsN), (Pplus, TsA), (Pminus, TsB), (Pchannel, TsC)],
'sprecovery': [(P0, 192),
               (Pplus, 384),
               (Pminus, 20),
               (Pchannel, 400)],
'spOVRrecovery': [(P0, 192),
               (Pplus, 1000),
               (Pminus, 20),
               (Pchannel, 400)],
'evrecovery': [(P0, 192),
               (Pplus, 384),
               (Pminus, 20),
               (Pplus, 20),
               (Pchannel, 400)],
'lng_recovery': [(P0, 192),
               (Pplus, 384),
               (Pminus, 384),
               (Pchannel, 400)],
'sprecoverySMITH': [(P0, 120),
               (Pplus, 130),
               (Pminus, 20),
               (Pchannel, 100)],
'spOVRrecoverySMITH': [(P0, 120),
               (Pplus, 600),
               (Pminus, 20),
               (Pchannel, 100)],
'AB0':[(P0, TaN),(Pminus, TaB)],
'AB1':[(P0, TaN),(Pplus,13),(Pminus, TaB)],
'AB2':[(P0, TaN),(Pplus,41),(Pminus, TaB)],
'AB3':[(P0, TaN),(Pplus,112),(Pminus, TaB)],
'ANB0':[(P0, TaN),(Pminus, TaB)],
'ANB1':[(P0, TaN),(Pplus,13),(P0, TaB),(Pminus, TaB)],
'ANB2':[(P0, TaN),(Pplus,41),(P0, TaB),(Pminus, TaB)],
'ANB3':[(P0, TaN),(Pplus,112),(P0, TaB),(Pminus, TaB)],
    }

def generate_herzfeld_scenarios(z_list=None, n_blocks=None, Tflips=None): 
    out_dict = {}
    for z in z_list:
        scenario_name =  f'herzfeld,z={z}'
        pert_per_z = []
        for n in range(n_blocks):
            hz = herzfeld_block(z, P1=Pplus,P2=Pminus,P0=P0, tau=1)
            pert_per_z.append((hz,len(hz)))
        out_dict.update({scenario_name:pert_per_z})
    return out_dict

hrz_params = {'z_list': [0.1,0.5,0.9], 'n_blocks': 25}
playlist.update(generate_herzfeld_scenarios(**hrz_params))

# %%
from coin_if import read_COIN_params
read_COIN_params('/fitted_parameters/')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from coin_if import read_COIN_params
#       2 read_COIN_params('/fitted_parameters/')
#
# ModuleNotFoundError: No module named 'coin_if'

# %%
# Out:
# {'I': {'sigma_q': 0.05,
#   'prior_mean_retention': 0.9,
#   'prior_precision_retention': 0.01,
#   'prior_precision_drift': 0.01,
#   'alpha_context': 50.0,
#   'rho_context': 0.1,
#   'sigma_motor_noise': 0.05,
#   'alpha_cue': 0.5},
#  'V': {'sigma_q': 0.1,
#   'prior_mean_retention': 0.9,
#   'prior_precision_retention': 0.1,
#   'prior_precision_drift': 0.1,
#   'alpha_context': 10.0,
#   'rho_context': 0.9,
#   'sigma_motor_noise': nan,
#   'alpha_cue': 10.0},
#  'S1': {'sigma_q': 0.1591,
#   'prior_mean_retention': 0.7996,
#   'prior_precision_retention': 0.69,
#   'prior_precision_drift': 0.00014,
#   'alpha_context': 31.0,
#   'rho_context': 0.3297,
#   'sigma_motor_noise': 0.0641,
#   'alpha_cue': nan},
#  'S2': {'sigma_q': 0.126,
#   'prior_mean_retention': 0.9488,
#   'prior_precision_retention': 0.00081,
#   'prior_precision_drift': 0.0062,
#   'alpha_context': 22.0,
#   'rho_context': 0.0869,
#   'sigma_motor_noise': 0.0661,
#   'alpha_cue': nan},
#  'S3': {'sigma_q': 0.0331,
#   'prior_mean_retention': 0.9308,
#   'prior_precision_retention': 0.0042,
#   'prior_precision_drift': 2.8e-05,
#   'alpha_context': 110000.0,
#   'rho_context': 0.1766,
#   'sigma_motor_noise': 0.0846,
#   'alpha_cue': nan},
#  'S4': {'sigma_q': 0.1237,
#   'prior_mean_retention': 0.9561,
#   'prior_precision_retention': 1.5e-05,
#   'prior_precision_drift': 0.0091,
#   'alpha_context': 7.1,
#   'rho_context': 0.0208,
#   'sigma_motor_noise': 0.0836,
#   'alpha_cue': nan},
#  'S5': {'sigma_q': 0.0668,
#   'prior_mean_retention': 0.9427,
#   'prior_precision_retention': 1.2e-05,
#   'prior_precision_drift': 4.7e-05,
#   'alpha_context': 1800.0,
#   'rho_context': 0.4522,
#   'sigma_motor_noise': 0.0961,
#   'alpha_cue': nan},
#  'S6': {'sigma_q': 0.0775,
#   'prior_mean_retention': 0.848,
#   'prior_precision_retention': 1.6e-05,
#   'prior_precision_drift': 0.0064,
#   'alpha_context': 0.0019,
#   'rho_context': 0.9999,
#   'sigma_motor_noise': 0.0978,
#   'alpha_cue': nan},
#  'S7': {'sigma_q': 0.1026,
#   'prior_mean_retention': 0.8088,
#   'prior_precision_retention': 0.011,
#   'prior_precision_drift': 0.001,
#   'alpha_context': 8.9,
#   'rho_context': 0.0016,
#   'sigma_motor_noise': 0.106,
#   'alpha_cue': nan},
#  'S8': {'sigma_q': 0.0392,
#   'prior_mean_retention': 0.7857,
#   'prior_precision_retention': 0.01,
#   'prior_precision_drift': 0.0059,
#   'alpha_context': 2.4,
#   'rho_context': 0.0152,
#   'sigma_motor_noise': 0.0929,
#   'alpha_cue': nan},
#  'E1': {'sigma_q': 0.1234,
#   'prior_mean_retention': 0.8827,
#   'prior_precision_retention': 0.018,
#   'prior_precision_drift': 0.0076,
#   'alpha_context': 120.0,
#   'rho_context': 0.2699,
#   'sigma_motor_noise': 0.0901,
#   'alpha_cue': nan},
#  'E2': {'sigma_q': 0.1441,
#   'prior_mean_retention': 0.9121,
#   'prior_precision_retention': 0.0003,
#   'prior_precision_drift': 0.0087,
#   'alpha_context': 380.0,
#   'rho_context': 0.1285,
#   'sigma_motor_noise': 0.0804,
#   'alpha_cue': nan},
#  'E3': {'sigma_q': 0.1119,
#   'prior_mean_retention': 0.9466,
#   'prior_precision_retention': 6e-05,
#   'prior_precision_drift': 0.0075,
#   'alpha_context': 230.0,
#   'rho_context': 0.007,
#   'sigma_motor_noise': 0.0781,
#   'alpha_cue': nan},
#  'E4': {'sigma_q': 0.1172,
#   'prior_mean_retention': 0.8578,
#   'prior_precision_retention': 0.012,
#   'prior_precision_drift': 0.0059,
#   'alpha_context': 12.0,
#   'rho_context': 0.0477,
#   'sigma_motor_noise': 0.0883,
#   'alpha_cue': nan},
#  'E5': {'sigma_q': 0.0705,
#   'prior_mean_retention': 0.946,
#   'prior_precision_retention': 0.0013,
#   'prior_precision_drift': 0.0051,
#   'alpha_context': 10000000.0,
#   'rho_context': 0.3911,
#   'sigma_motor_noise': 0.0715,
#   'alpha_cue': nan},
#  'E6': {'sigma_q': 0.0559,
#   'prior_mean_retention': 0.9643,
#   'prior_precision_retention': 0.003,
#   'prior_precision_drift': 0.0049,
#   'alpha_context': 29.0,
#   'rho_context': 0.0044,
#   'sigma_motor_noise': 0.0966,
#   'alpha_cue': nan},
#  'E7': {'sigma_q': 0.0926,
#   'prior_mean_retention': 0.9422,
#   'prior_precision_retention': 1.6e-05,
#   'prior_precision_drift': 0.0033,
#   'alpha_context': 3700000.0,
#   'rho_context': 0.0003,
#   'sigma_motor_noise': 0.0936,
#   'alpha_cue': nan},
#  'E8': {'sigma_q': 0.099,
#   'prior_mean_retention': 0.8405,
#   'prior_precision_retention': 0.0023,
#   'prior_precision_drift': 0.0071,
#   'alpha_context': 160.0,
#   'rho_context': 0.5336,
#   'sigma_motor_noise': 0.1,
#   'alpha_cue': nan},
#  'A': {'sigma_q': 0.0089,
#   'prior_mean_retention': 0.9425,
#   'prior_precision_retention': 0.0012,
#   'prior_precision_drift': 0.00082,
#   'alpha_context': 9.0,
#   'rho_context': 0.2501,
#   'sigma_motor_noise': 0.0182,
#   'alpha_cue': nan},
#  'M1': {'sigma_q': 0.036,
#   'prior_mean_retention': 0.6575,
#   'prior_precision_retention': 0.0011,
#   'prior_precision_drift': 1e-05,
#   'alpha_context': 2400.0,
#   'rho_context': 0.0029,
#   'sigma_motor_noise': 0.0865,
#   'alpha_cue': 19.0},
#  'M2': {'sigma_q': 0.0412,
#   'prior_mean_retention': 0.7274,
#   'prior_precision_retention': 0.0089,
#   'prior_precision_drift': 0.013,
#   'alpha_context': 0.13,
#   'rho_context': 0.0062,
#   'sigma_motor_noise': 0.0921,
#   'alpha_cue': 3000.0},
#  'M3': {'sigma_q': 0.0155,
#   'prior_mean_retention': 0.9473,
#   'prior_precision_retention': 0.001,
#   'prior_precision_drift': 0.00079,
#   'alpha_context': 0.0083,
#   'rho_context': 0.0003,
#   'sigma_motor_noise': 0.0979,
#   'alpha_cue': 1800.0},
#  'M4': {'sigma_q': 0.0572,
#   'prior_mean_retention': 0.6986,
#   'prior_precision_retention': 0.0048,
#   'prior_precision_drift': 0.008,
#   'alpha_context': 28000.0,
#   'rho_context': 0.1732,
#   'sigma_motor_noise': 0.1056,
#   'alpha_cue': 1.3},
#  'M5': {'sigma_q': 0.0574,
#   'prior_mean_retention': 0.842,
#   'prior_precision_retention': 9.5e-05,
#   'prior_precision_drift': 0.0005,
#   'alpha_context': 2200000.0,
#   'rho_context': 0.0352,
#   'sigma_motor_noise': 0.1187,
#   'alpha_cue': 5.9},
#  'M6': {'sigma_q': 0.0938,
#   'prior_mean_retention': 0.7309,
#   'prior_precision_retention': 0.0011,
#   'prior_precision_drift': 0.0015,
#   'alpha_context': 22000.0,
#   'rho_context': 0.0118,
#   'sigma_motor_noise': 0.1153,
#   'alpha_cue': 15.0},
#  'M7': {'sigma_q': 0.0594,
#   'prior_mean_retention': 0.8744,
#   'prior_precision_retention': 2.4e-05,
#   'prior_precision_drift': 0.0023,
#   'alpha_context': 5200000.0,
#   'rho_context': 0.0007,
#   'sigma_motor_noise': 0.1245,
#   'alpha_cue': 99.0},
#  'M8': {'sigma_q': 0.0708,
#   'prior_mean_retention': 0.7676,
#   'prior_precision_retention': 9.6e-05,
#   'prior_precision_drift': 0.0016,
#   'alpha_context': 3100000.0,
#   'rho_context': 0.004,
#   'sigma_motor_noise': 0.1206,
#   'alpha_cue': 7.0},
#  'M9': {'sigma_q': 0.0586,
#   'prior_mean_retention': 0.8751,
#   'prior_precision_retention': 0.00028,
#   'prior_precision_drift': 0.0019,
#   'alpha_context': 1900000.0,
#   'rho_context': 0.0139,
#   'sigma_motor_noise': 0.1206,
#   'alpha_cue': 82.0},
#  'M10': {'sigma_q': 0.0589,
#   'prior_mean_retention': 0.8949,
#   'prior_precision_retention': 0.00013,
#   'prior_precision_drift': 0.00073,
#   'alpha_context': 340000.0,
#   'rho_context': 0.1347,
#   'sigma_motor_noise': 0.1258,
#   'alpha_cue': 0.24},
#  'M11': {'sigma_q': 0.0419,
#   'prior_mean_retention': 0.9047,
#   'prior_precision_retention': 1.1e-05,
#   'prior_precision_drift': 0.00054,
#   'alpha_context': 71.0,
#   'rho_context': 0.2443,
#   'sigma_motor_noise': 0.1262,
#   'alpha_cue': 0.35},
#  'M12': {'sigma_q': 0.0576,
#   'prior_mean_retention': 0.8587,
#   'prior_precision_retention': 0.00015,
#   'prior_precision_drift': 0.0011,
#   'alpha_context': 4600.0,
#   'rho_context': 0.2205,
#   'sigma_motor_noise': 0.1333,
#   'alpha_cue': 2.3},
#  'M13': {'sigma_q': 0.056,
#   'prior_mean_retention': 0.9164,
#   'prior_precision_retention': 3.3e-05,
#   'prior_precision_drift': 0.0014,
#   'alpha_context': 18.0,
#   'rho_context': 0.102,
#   'sigma_motor_noise': 0.1366,
#   'alpha_cue': 0.97},
#  'M14': {'sigma_q': 0.0364,
#   'prior_mean_retention': 0.8833,
#   'prior_precision_retention': 6.1e-05,
#   'prior_precision_drift': 0.0044,
#   'alpha_context': 490.0,
#   'rho_context': 0.0041,
#   'sigma_motor_noise': 0.141,
#   'alpha_cue': 0.4},
#  'M15': {'sigma_q': 0.0543,
#   'prior_mean_retention': 0.81,
#   'prior_precision_retention': 0.0044,
#   'prior_precision_drift': 0.00083,
#   'alpha_context': 0.0068,
#   'rho_context': 0.0508,
#   'sigma_motor_noise': 0.1433,
#   'alpha_cue': 0.0075},
#  'M16': {'sigma_q': 0.0546,
#   'prior_mean_retention': 0.8249,
#   'prior_precision_retention': 3e-05,
#   'prior_precision_drift': 0.0011,
#   'alpha_context': 27000.0,
#   'rho_context': 0.3736,
#   'sigma_motor_noise': 0.1423,
#   'alpha_cue': 0.012},
#  'M17': {'sigma_q': 0.0485,
#   'prior_mean_retention': 0.8534,
#   'prior_precision_retention': 0.0012,
#   'prior_precision_drift': 0.00049,
#   'alpha_context': 140000.0,
#   'rho_context': 0.0019,
#   'sigma_motor_noise': 0.1487,
#   'alpha_cue': 60.0},
#  'M18': {'sigma_q': 0.0586,
#   'prior_mean_retention': 0.7947,
#   'prior_precision_retention': 0.0053,
#   'prior_precision_drift': 0.013,
#   'alpha_context': 1200.0,
#   'rho_context': 0.0002,
#   'sigma_motor_noise': 0.1542,
#   'alpha_cue': 0.58},
#  'M19': {'sigma_q': 0.1233,
#   'prior_mean_retention': 0.7211,
#   'prior_precision_retention': 0.00013,
#   'prior_precision_drift': 0.0044,
#   'alpha_context': 4100.0,
#   'rho_context': 0.0002,
#   'sigma_motor_noise': 0.161,
#   'alpha_cue': 35.0},
#  'M20': {'sigma_q': 0.021,
#   'prior_mean_retention': 0.9711,
#   'prior_precision_retention': 0.00016,
#   'prior_precision_drift': 0.00086,
#   'alpha_context': 0.029,
#   'rho_context': 0.0004,
#   'sigma_motor_noise': 0.1534,
#   'alpha_cue': 660.0},
#  'M21': {'sigma_q': 0.0976,
#   'prior_mean_retention': 0.8624,
#   'prior_precision_retention': 0.00041,
#   'prior_precision_drift': 0.0084,
#   'alpha_context': 9600000.0,
#   'rho_context': 0.1154,
#   'sigma_motor_noise': 0.1464,
#   'alpha_cue': 18.0},
#  'M22': {'sigma_q': 0.1091,
#   'prior_mean_retention': 0.7853,
#   'prior_precision_retention': 0.00076,
#   'prior_precision_drift': 0.0039,
#   'alpha_context': 2100.0,
#   'rho_context': 0.0314,
#   'sigma_motor_noise': 0.1644,
#   'alpha_cue': 1.0},
#  'M23': {'sigma_q': 0.0708,
#   'prior_mean_retention': 0.8501,
#   'prior_precision_retention': 0.003,
#   'prior_precision_drift': 0.0019,
#   'alpha_context': 150.0,
#   'rho_context': 0.022,
#   'sigma_motor_noise': 0.1905,
#   'alpha_cue': 35.0},
#  'M24': {'sigma_q': 0.0898,
#   'prior_mean_retention': 0.9185,
#   'prior_precision_retention': 0.00018,
#   'prior_precision_drift': 0.003,
#   'alpha_context': 6.8,
#   'rho_context': 0.2249,
#   'sigma_motor_noise': 0.1989,
#   'alpha_cue': 1.5}}

# %%
frog_playlist = {
f'frogs{f}': [(P0,TfN1),((P0,Pplus),TfA_),(P0,TfN2)] for f,TfA_ in enumerate([300,600, 900])}

frog_playlist_a = {
f'anti_frogs{f}': [(P0,TfN1),(Pplus,TfA_),(P0,TfN2)] for f,TfA_ in enumerate([300,600, 900])} 

frog_playlist.update(frog_playlist_a)

# %%
# baseline_settings = {'criterion':'MSE', 'k':[0.1,0,5], 'learning_rate':0.5e-4, 'sigma_noi':0.0, 'tau_u':1}
# baseline_settings = {'criterion':'MSE', 'k':[0.5,0,2], 'learning_rate':0.5e-4, 'sigma_noi':0.0, 'tau_u':1}
err_based_settings = {'k':[0,0,1], 'tau_u':1} #applies to dual rate model as well as to Herzfeld14 model


# dual_rate_flags = {'apply_initial_state': False, 'save_model_at_init':False, 'model_type': 'numpy'}
err_based_flags_runner = {'model_type': 'numpy',
                   'initial_state': [0,0,0], 
                   'save_model_at_init':False, 
                  'do_backprop': False}

nn_settings = {'criterion':'MSE', 'k':[0.3,0,1], 'learning_rate':0.5e-4, 'sigma_noi':0.0, 'tau_u':1}

coin_settings = {
    "runner_method_alias": "blackbox",  
    "model_type": "coin",               # Distinguish from 'torch' or 'numpy'
    "do_backprop": False,               # No training/backpropagation for COIN
    "load_model_at_init": False,        # COIN doesn’t support state_dict saving/loading
    "save_model_at_init": False,        # Ensure no torch parameter saving is attempted
    'initial_state': [], 
    "tau_u": 1,                        # Can be set if needed (may be unused in COIN mode)
}


test_vec= np.stack([np.linspace(-10,10,200), 
                    np.zeros(200),
                    np.zeros(200)]).T

# %%
err_based_flags_model = dict(input_proj_vec=[0,0,1])

model_args_s = {}
model_args_s['Colman'] = dict(a_f=0.55,a_s=0.995, b_f=0.4, b_s=0.05, 
                              info={'model_type':'dual_rate','runner_settings':err_based_settings}) #approx means from Coltman et al.
model_args_s['Smith'] = dict(a_f=0.59,a_s=0.992, b_f=0.21, b_s=0.02, 
                             info={'model_type':'dual_rate','runner_settings':err_based_settings})  #Smith et al
model_args_s['Herzfeld'] = dict(
                             info={'model_type':'herzfeld14','runner_settings':err_based_settings})  #Herzfeld et al 14
# model_args_s['someNN'] =  dict(n_inputs = 3,
#                                 n_hidden = 4*512,
#                                 n_outs = 1,
#                                 en_bias = False,
#                                 b_high=5, first_layer_init='uniform_unity',
#                                 first_layer_weights_trainable = True,
#                                 nl = lambda : OneOverSqr(w=0.5,c=-0.0), 
#                                skip_gain= 0.5, info={'model_type':'mlp','runner_settings':nn_settings})

# %%
results = {}
frog_results = {}

# %%
for setting,model_args  in model_args_s.items():
    if model_args['info']['model_type'] == 'mlp':
        model_class = MLP
        flags_runner = {}
        flags_model = {}
    elif model_args['info']['model_type'] == 'dual_rate':
        model_class = DualRateModel
        flags_runner = err_based_flags_runner
        flags_model =err_based_flags_model
    elif model_args['info']['model_type'] == 'herzfeld14':
        model_class = Herzfeld14Model
        flags_runner = err_based_flags_runner
        flags_model =err_based_flags_model
    elif model_args['info']['model_type'] == 'coin':
        model_class = COINWrapper
        flags_runner = {} #err_based_flags_runner
        flags_model = {} #err_based_flags_model
    else:
        raise ValueError
        
        
#     runner = Runner(model=model_class(**{**model_args, **flags_model}),
#                     test_vec=None,
#                     **{**model_args['info']['runner_settings'],**flags_runner})

            
    runner = Runner(model_class=model_class, model_construct_args={**model_args, **flags_model},
                    test_vec=None,
                    **{**model_args['info']['runner_settings'],**flags_runner})
    
    results[setting] = runner.run_multiple(playlist)
    frog_results[setting] = runner.run_multiple(frog_playlist)
# Out:
# running scenario: frogs
# running scenario: anti_frogs
# running scenario: savings
# running scenario: sprecovery
# running scenario: spOVRrecovery
# running scenario: evrecovery
# running scenario: lng_recovery
# running scenario: sprecoverySMITH
# running scenario: spOVRrecoverySMITH
# running scenario: AB0
# running scenario: AB1
# running scenario: AB2
# running scenario: AB3
# running scenario: ANB0
# running scenario: ANB1
# running scenario: ANB2
# running scenario: ANB3
# running scenario: herzfeld,z=0.1
# running scenario: herzfeld,z=0.5
# running scenario: herzfeld,z=0.9
# running scenario: frogs0
# running scenario: frogs1
# running scenario: frogs2
# running scenario: anti_frogs0
# running scenario: anti_frogs1
# running scenario: anti_frogs2
# running scenario: frogs
# running scenario: anti_frogs
# running scenario: savings
# running scenario: sprecovery
# running scenario: spOVRrecovery
# running scenario: evrecovery
# running scenario: lng_recovery
# running scenario: sprecoverySMITH
# running scenario: spOVRrecoverySMITH
# running scenario: AB0
# running scenario: AB1
# running scenario: AB2
# running scenario: AB3
# running scenario: ANB0
# running scenario: ANB1
# running scenario: ANB2
# running scenario: ANB3
# running scenario: herzfeld,z=0.1
# running scenario: herzfeld,z=0.5
# running scenario: herzfeld,z=0.9
# running scenario: frogs0
# running scenario: frogs1
# running scenario: frogs2
# running scenario: anti_frogs0
# running scenario: anti_frogs1
# running scenario: anti_frogs2
# running scenario: frogs
# running scenario: anti_frogs
# running scenario: savings
# running scenario: sprecovery
# running scenario: spOVRrecovery
# running scenario: evrecovery
# running scenario: lng_recovery
# running scenario: sprecoverySMITH
# running scenario: spOVRrecoverySMITH
# running scenario: AB0
# running scenario: AB1
# running scenario: AB2
# running scenario: AB3
# running scenario: ANB0
# running scenario: ANB1
# running scenario: ANB2
# running scenario: ANB3
# running scenario: herzfeld,z=0.1
# running scenario: herzfeld,z=0.5
# running scenario: herzfeld,z=0.9
# running scenario: frogs0
# running scenario: frogs1
# running scenario: frogs2
# running scenario: anti_frogs0
# running scenario: anti_frogs1
# running scenario: anti_frogs2

# %%
antero_colors=['tab:red','tab:blue','tab:orange','tab:green']
def do_plots(results,playlist,figsize=(24, 12)):
    plt.figure(figsize=figsize)
    plt.subplot(2,3,1)
    plot_segments(results['savings'].u_lp,
              t_start=playlist['savings'][0][1],
              n_segments=2,
              t_increment=playlist['savings'][0][1]+playlist['savings'][1][1]+playlist['savings'][2][1]+playlist['savings'][3][1],
              t_segment=playlist['savings'][1][1],             
             )
    plt.subplot(2,3,2)
    plot_by_key(results, ['frogs','anti_frogs'],visu_offsets = [0, 0.00])
    plt.xlabel('epochs')
    plt.ylabel('u(epoch) [au]')
    plt.subplot(2,3,3)
    plot_by_key(results,
                ['sprecovery','spOVRrecovery','lng_recovery','evrecovery'],
                colors=['tab:red','tab:blue','tab:orange','tab:green'],
                align_end=True,
                visu_offsets=[0]*10,
               )
    
    plt.subplot(2,3,4)
    plot_by_key(results,
                ['AB0','AB1','AB2','AB3'],
                colors=antero_colors,
                align_end=True,
                visu_offsets=[0]*10,
               )
    
    plt.subplot(2,3,5)
    plot_by_key(results,
                ['ANB0','ANB1','ANB2','ANB3'],
                colors=antero_colors,
                align_end=True,
                visu_offsets=[0]*10,
               )
    
    plt.subplot(2,3,6)
    for iz, z in enumerate(hrz_params['z_list']):
        deltas = []
        scenario = f'herzfeld,z={z}'
        this_result = results[scenario]
        block_length = playlist[scenario]
        pointer = 0
        for bb in range(hrz_params['n_blocks']):
            block_length = playlist[scenario][bb][-1]
            pointer += block_length
            deltas.append(this_result.u_lp[pointer-1]-this_result.u_lp[pointer-3])            

        plt.plot(deltas,'x',label = f'z={z}')
    plt.legend(loc='upper right')
    plt.xlabel('block #')
    plt.ylabel('adaptation delta channel2-channel1')

# %% [markdown]
# ## Evaluating basic checklist

# %%
for name, these_results in results.items():
    do_plots(these_results,playlist)
    plt.subplot(2,3,1)
    plt.title(f'savings')
    plt.ylabel(name)
    plt.subplot(2,3,2)
    plt.title(f'abrupt/gradual')
    plt.subplot(2,3,3)
    plt.title(f'spontaneous/evoked recovery')
    plt.grid(True)
    plt.subplot(2,3,4)
    plt.ylabel(name)
    plt.show()

# %% [markdown]
# # zooming into spontaneous recovery at time-intervals as in Smith paper

# %%
for ii, model_name in enumerate(['Smith','someNN']):
    plot_by_key(results[model_name],
                    ['sprecoverySMITH'],
                    colors=[antero_colors[ii]], # a hack to perserve our standard color codind
                    align_end=True,
                    visu_offsets=[0]*10,
                   )
plt.grid()
# plt.xlim([-1000,-300])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 for ii, model_name in enumerate(['Smith','someNN']):
# ----> 2     plot_by_key(results[model_name],
#       3                     ['sprecoverySMITH'],
#       4                     colors=[antero_colors[ii]], # a hack to perserve our standard color codind
#       5                     align_end=True,
#       6                     visu_offsets=[0]*10,
#       7                    )
#       8 plt.grid()
#
# KeyError: 'someNN'

# %% [markdown]
# # Overlearning

# %%
plt.figure(figsize=(15,5))

for ii, model_name in enumerate(['Smith','COIN']):
    plt.subplot(1,2,ii+1)
    plot_by_key(results[model_name],
                    ['sprecoverySMITH','spOVRrecoverySMITH'],
                    colors=antero_colors,
                    align_end=True,
                    visu_offsets=[0]*10,
                   )
    plt.title(model_name)
    plt.grid()

# %% [markdown]
# ## Zoom into anterograde interference
# We fist plot it with appropreate zoom, then replot on logarithmic scale to show constant convergence rate

# %%
for ii, model_name in enumerate(['Smith','someNN']):
    plt.subplot(1,2,ii+1)
    plot_by_key(results[model_name],
                    ['AB0','AB1','AB2','AB3'],
                    colors=['tab:red','tab:blue','tab:orange','tab:green'],
                    align_end=True,
                    visu_offsets=[0]*10,
                   )
    plt.xlim([-800,-400])
# plt.ylim([-1,0])

# %%
for ii, model_name in enumerate(['Smith','someNN']):
    these_results=results[model_name]
    plt.figure(figsize=(15,5))
    for s, scenario in enumerate(['AB0','AB1','AB2','AB3']):
        y= these_results[scenario].u_lp
        x = np.arange(len(y))
        plt.subplot(1,3,1)
        plt.plot(x,y, color=antero_colors[s])
        plt.ylabel(model_name)
        plt.subplot(1,3,2)
        plt.semilogy(x,y-y[-1],color=antero_colors[s])
        plt.subplot(1,3,3)
        plt.plot(x[300:600-1], np.diff(np.log10(y[300:600]-y[-1])),color=antero_colors[s])

# %% [markdown]
# # Ensuring that boiling-frog effect does not show up for longer adaptations

# %%
plt.figure(figsize=(18,9))
for rr, (name, these_results) in enumerate(frog_results.items()):
    for f in range(3):
        plt.subplot(3,3,3*rr+f+1)
        plot_by_key(these_results, [f'frogs{f}',f'anti_frogs{f}'],visu_offsets = [0, 0.00])
        plt.xlabel('epochs')
        plt.ylabel('u(epoch) [au]')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       2 for rr, (name, these_results) in enumerate(frog_results.items()):
#       3     for f in range(3):
# ----> 4         plt.subplot(3,3,3*rr+f+1)
#       5         plot_by_key(these_results, [f'frogs{f}',f'anti_frogs{f}'],visu_offsets = [0, 0.00])
#       6         plt.xlabel('epochs')
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/pyplot.py:1289, in subplot(*args, **kwargs)
#    1286 fig = gcf()
#    1288 # First, search for an existing subplot with a matching spec.
# -> 1289 key = SubplotSpec._from_subplot_args(fig, args)
#    1291 for ax in fig.axes:
#    1292     # if we found an axes at the position sort out if we can re-use it
#    1293     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1294         # if the user passed no kwargs, re-use
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/gridspec.py:608, in SubplotSpec._from_subplot_args(figure, args)
#     606 else:
#     607     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 608         raise ValueError(
#     609             f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     610     i = j = num
#     611 return gs[i-1:j]
#
# ValueError: num must be 1 <= num <= 9, not 10

# %%
for ii, model_name in enumerate(['Smith','someNN']):
    these_results=results[model_name]
    plt.figure(figsize=(15,5))
    for s, scenario in enumerate(['savings']):
        y= these_results[scenario].u_lp
        x = np.arange(len(y))
#         plt.subplot(1,3,1)
        plt.plot(x,y, color=antero_colors[s])
        plt.plot(x,y,'x', color=antero_colors[s])
        plt.ylabel(model_name)
